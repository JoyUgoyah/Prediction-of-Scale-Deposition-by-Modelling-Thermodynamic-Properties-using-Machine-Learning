# %% [markdown]
# # Project Objective
#
# This notebook uses machine learning engineering, written in python language, to build models from different algorithms in the ScikitLearn library that will predict the scale formation (or not) in different oilfields. The models will eliminate the need for equations and correlations that are based on certain assumptions and do not capture significant underlying relationships. The model developed predicts scale formation with a high probability and likewise predict no scale formation with high certaintiy. It presents an effective way of monitoring scaling in an oilfield to make better proactive decisions.

# %%
# Import basic libraries for data wrangling, analysis and visualization

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# The data being used for model building in this research was collected from the following secondary data sources: Chike (2010), and Al-hajri et al. (2020). It includes measured properties from wells in different fields in the Niger Delta and other oil producing  regions outside Africa. The data set is available on an online spreadsheet compiled by me at https://drive.google.com/file/d/1k5JzxaNUQR314V37S47fjHOjmrazFI-i/view?usp=sharing

# %%
# Load scale dataset from google drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
scale_data = pd.read_excel('/content/gdrive/My Drive/Final_Year_Project/scale_data.xlsx')

# %%
# Show data samples
scale_data.sample(15, random_state=12)
# Out:
#      Well No  Temperature (oF)  ...  Inspection Result  Scale Type
# 374      104               NaN  ...              scale       CaCO3
# 287       89               NaN  ...              scale       CaCO3
# 152       56               NaN  ...              scale       CaCO3
# 392      107               NaN  ...              scale       CaCO3
# 14        15             130.0  ...           no scale       CaCO3
# 465      119               NaN  ...           no scale       CaCO3
# 275       85               NaN  ...              scale       CaCO3
# 290       89               NaN  ...              scale       CaCO3
# 268       83               NaN  ...              scale       CaCO3
# 0          1             120.0  ...           no scale       CaCO3
# 486      119               NaN  ...           no scale       CaCO3
# 306       93               NaN  ...              scale       CaCO3
# 206       65               NaN  ...              scale       CaCO3
# 270       84               NaN  ...              scale       CaCO3
# 504      124               NaN  ...           no scale       CaCO3
#
# [15 rows x 17 columns]

# %% [markdown]
# The data set contains thermodynamic and compositional information about different wells indicated by the given well number and showing the result of inspection of well for scale or no scale. The sample shows that one well can appear more than once with different data values taken at different times during the life of the well. The occurence of scaling is indicated as 'scale' or 'no scale' in the `Inspection Result` column. The samples also show that there are a lot of missing values indicated as 'NaN', this is as a result of incomplete information since the data was sourced for from multiple sources.
#
# Next, more information about the nature of the data set is obtained to enable better analysis of how the data set can be manipulated to build the best possible models.

# %%
scale_data.columns # to get column names
# Out:
# Index(['Well No', 'Temperature (oF)', 'Pressure (psia)', 'CO2 mole frac.',
#        'pH', 'Ca2+ (ppm)', 'Na+ (ppm)', 'Mg2+ (ppm)', 'Fe2+ (ppm)',
#        'HCO3- (ppm)', 'SO4 2-(ppm)', 'Cl- (ppm)', 'CO3 2- (ppm)', 'Ba2+ (ppm)',
#        'TDS (ppm)', 'Inspection Result', 'Scale Type'],
#       dtype='object')

# %%
# Rename columns for easier manipulation
scale_data.rename(columns={'Temperature (oF)': 'T', 'Pressure (psia)':'P', 'CO2 mole frac.':'XCO2',
       'Ca2+ (ppm)':'Ca2+', 'Na+ (ppm)':'Na+', 'Mg2+ (ppm)':'Mg2+', 'Fe2+ (ppm)':'Fe2+',
       'HCO3- (ppm)':'HCO3-', 'SO4 2-(ppm)':'SO4 2-', 'Cl- (ppm)':'Cl-', 'CO3 2- (ppm)':'CO3 2-', 'Ba2+ (ppm)':'Ba2+',
       'TDS (ppm)':'TDS'}, inplace=True)

# %%
# See information on data set
scale_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541 entries, 0 to 540
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Well No            541 non-null    int64
#  1   T                  36 non-null     float64
#  2   P                  36 non-null     float64
#  3   XCO2               31 non-null     float64
#  4   pH                 535 non-null    float64
#  5   Ca2+               541 non-null    float64
#  6   Na+                540 non-null    float64
#  7   Mg2+               540 non-null    float64
#  8   Fe2+               30 non-null     float64
#  9   HCO3-              541 non-null    float64
#  10  SO4 2-             539 non-null    float64
#  11  Cl-                35 non-null     float64
#  12  CO3 2-             30 non-null     float64
#  13  Ba2+               5 non-null      float64
#  14  TDS                510 non-null    float64
#  15  Inspection Result  541 non-null    object
#  16  Scale Type         540 non-null    object
# dtypes: float64(14), int64(1), object(2)
# memory usage: 72.0+ KB

# %% [markdown]
# The data set contains 541 entries, these will be refered to as instances going forward in this notebook. The dataframe has 17 columns, of which only 3 of the features (`Well no`, `Ca2+`, and `HCO3-`) and the target variable (`Inspection Result`) have no null instances. This is a result of compiling data from multiple sources where some sources do not contain certain variables. However, from the objective of this research, every feature is important for building a scale predicting model that performs efficiently on the field. In the data preprocessing stage, the null values will be handled in a way that allows the building of a robust machine learning model. The dataframe has 14 columns containing float values, 1 integer column and 2 object value columns, a total of 17 columns. These values will be handled accordingly.

# %% [markdown]
# Getting a statistical description on the numerical (float and integer) values and the categorical values (object) as well serves as guide in determining the best strategy for handling the null values in a way that maintains the models integrity

# %%
# Get statistical  description for numerical values
scale_data.describe()
# Out:
#           Well No           T  ...       Ba2+            TDS
# count  541.000000   36.000000  ...   5.000000     510.000000
# mean    80.323475  132.277778  ...  17.460000   93711.439216
# std     32.493315   50.172469  ...   8.864705   44788.682017
# min      1.000000   73.400000  ...   4.900000     228.000000
# 25%     53.000000   77.000000  ...  14.000000   62793.500000
# 50%     84.000000  130.000000  ...  18.000000   87518.500000
# 75%    110.000000  162.750000  ...  21.700000  116601.750000
# max    130.000000  250.000000  ...  28.700000  236911.000000
#
# [8 rows x 15 columns]

# %% [markdown]
# Most of the features do not show a normal distribution as their Standard deviations are far from zero , this implies that imputing mean values to fill the null values will not be the best strategy. Dropping the rows with null values will leave the data set with less than quarter its intial size and too few data points to use for model building. Visualizing the data using different methods can give a better understanding of the data behaviour.

# %%
# Get statistical  description for categorical values
scale_data.describe(include=['object'])
# Out:
#        Inspection Result Scale Type
# count                541        540
# unique                 2          2
# top                scale      CaCO3
# freq                 367        535

# %% [markdown]
# The target variable, `Inspection Result` has 2 unique values as mentioned ealier, it is unbalanced with scale occuring more times than no scale. Because of this, using algorithms that don't classify unbalanced data well e.g. Logistic regression, will be ineffective.
# The most occuring `scale type` is CaCO3. The catgorical values will be converted to numeral by encoding technique.

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Data Visualization

# %% [markdown]
# Evaluating the correlation between the data features will show how the different variables interact with each other showing the degree of importance of the different in classifying the target data and also determining the suitablity of different features for predicting other features that have null instances (rows).

# %%
# Visualize the data correlation on a heatmap

fig, ax = plt.subplots(figsize=(12,10))

sns.heatmap(scale_data.corr(), cmap=('RdYlGn'))

# %% [markdown]
# The blank spaces on the map show that the variables share no instances (due to null values). For instance, Ba2+ can't be predicted using TDS, pH, Fe2+ o CO3.
#
# Well no is just an indicator of the different wells from which the data was measured. Even though multiple instances were measured from some wells, the variables (note: not values) obtained from each well are the same, therefore any correlation seen is not a relevant relationship for prediction.
#
# Pressure and pH are highly positively correlated, while pressure shows an average negative correlation with Fe2+, this may not imply a real relationship in the PVT relationship of petroleum engineering. Pressure shows no correlation with temperature on the map.
#
# Temperature shows a slight positive correlation with most of the ion concentrations. It also shows a high negative correlation with pH and HCO3-. This makes all these variables suitable for predicting the temperature values.
#
# CO2 mole fraction has a very slight correlation with the other variables and almost no correlation with pH.
#
# pH shows a strong negative correlations with most of the other variables, a strong +ve correlation with pressure and contrary to the opinion of past litera

# %%
# A scatter plot betweem the numerical variables

from pandas.plotting import scatter_matrix

scatter_matrix(scale_data, figsize=(16,14));

# %%
sns.lmplot(x="TDS", y="HCO3-", hue="Inspection Result", data=scale_data, palette="Set1", height=7)

# %%
# Drop columns that do not appear to be of great importance if any
scale_data.drop('Ba2+', axis=1, inplace=True)

# %%
scale_data.sample(5)
# Out:
#      Well No   T   P  XCO2  ...  CO3 2-       TDS  Inspection Result  Scale Type
# 208       65 NaN NaN   NaN  ...     NaN  164843.0              scale       CaCO3
# 172       59 NaN NaN   NaN  ...     NaN   84083.0              scale       CaCO3
# 505      124 NaN NaN   NaN  ...     NaN   89659.0           no scale       CaCO3
# 123       50 NaN NaN   NaN  ...     NaN   12228.0              scale       CaCO3
# 57        40 NaN NaN   NaN  ...     NaN   23306.0              scale       CaCO3
#
# [5 rows x 16 columns]

# %%
# Boxplots to check for outliers

fig, ax = plt.subplots(figsize=(12,10))

sns.boxplot(data=scale_data, ax=ax, orient='h')

plt.show()

# %% [markdown]
# The box plot above shows that the data features fall within different ranges of values. There also a lot of columns with noisy data falling outside the top percentile of the data range. These conditions of the data set call for possible standardization or normalization. This line of action will be considered after building and evaluating a test-run-model with the unstandardized data set.

# %%
# Encode categorical data
scale_data['Inspection Result'].replace('scale', 1, inplace=True)

# %%
# Encode categorical data
scale_data['Inspection Result'].replace('no scale', 0, inplace=True)

# %%
scale_data['Inspection Result']
# Out:
# 0      0
# 1      1
# 2      0
# 3      0
# 4      0
#       ..
# 536    0
# 537    0
# 538    0
# 539    0
# 540    1
# Name: Inspection Result, Length: 541, dtype: int64

# %%
# Plot to check if distribution is normal
# let's use seaborn to plot the skewness of the data using kernel density estimate

sns.distplot(scale_data['T'], bins=20);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Plot to check if distribution is normal
# let's use seaborn to plot the skewness of the data using kernel density estimate


sns.distplot(scale_data['P'], bins=20);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Plot to check if distribution is normal
# let's use seaborn to plot the skewness of the data using kernel density estimate


sns.distplot(scale_data['XCO2'], bins=20);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Plot to check if distribution is normal
# let's use seaborn to plot the skewness of the data using kernel density estimate

sns.distplot(scale_data['pH'],  bins=20);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Plot to check if distribution is normal
# let's use seaborn to plot the skewness of the data using kernel density estimate

sns.distplot(scale_data['Ca2+'], bins=20);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Plot to check if distribution is normal
# let's use seaborn to plot the skewness of the data using kernel density estimate

sns.distplot(scale_data['Na+'], bins=20);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Plot to check if distribution is normal
# let's use seaborn to plot the skewness of the data using kernel density estimate

sns.distplot(scale_data['Mg2+'], bins=20);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Plot to check if distribution is normal
# let's use seaborn to plot the skewness of the data using kernel density estimate

sns.distplot(scale_data['Fe2+'], bins=20);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Plot to check if distribution is normal
# let's use seaborn to plot the skewness of the data using kernel density estimate

sns.distplot(scale_data['HCO3-'], bins=20);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Plot to check if distribution is normal
# let's use seaborn to plot the skewness of the data using kernel density estimate

sns.distplot(scale_data['SO4 2-'], bins=20);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Plot to check if distribution is normal
# let's use seaborn to plot the skewness of the data using kernel density estimate

sns.distplot(scale_data['Cl-'], bins=20);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Plot to check if distribution is normal
# let's use seaborn to plot the skewness of the data using kernel density estimate

sns.distplot(scale_data['CO3 2-'], bins=20);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Plot to check if distribution is normal
# let's use seaborn to plot the skewness of the data using kernel density estimate

sns.distplot(scale_data['TDS'], bins=20);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
scale = sum(scale_data['Inspection Result']==1)
no_scale = sum(scale_data['Inspection Result']==0)

print(scale, no_scale)
# Out:
# 367 174

# %%
# Plot to check if distribution is normal
# let's use seaborn to plot the skewness of the data using kernel density estimate

result = ['scale', 'no scale']
sum_of_cases = [scale, no_scale]

plt.bar(result, sum_of_cases);
plt.title('Inspection Result')
# Out:
# Text(0.5, 1.0, 'Inspection Result')

# %%
CaCO3 = sum(scale_data['Scale Type']=='CaCO3')
BaSO4 = sum(scale_data['Scale Type']=='BaSO4')

print(CaCO3, BaSO4)
# Out:
# 535 5

# %%
result = ['CaCO3', 'BaSO4']
sum_of_cases = [CaCO3,  BaSO4]

plt.bar(result, sum_of_cases);
plt.title('Scale Type')
# Out:
# Text(0.5, 1.0, 'Scale Type')

# %% [markdown]
# ### Filling Null Values
#
# Here 3 methods are experimented for imputing null values. The different data sets will be evaluated by building an experimental model with them and then the highest performing data set will be used for further development.

# %% [markdown]
# #### Using datawig to generate null values

# %%
# !pip install datawig
# Out:
# Collecting datawig
#   Downloading datawig-0.2.0.tar.gz (61 kB)
#      |████████████████████████████████| 61 kB 63 kB/s
# Collecting scikit-learn[alldeps]==0.22.1
#   Downloading scikit_learn-0.22.1-cp37-cp37m-manylinux1_x86_64.whl (7.0 MB)
#      |████████████████████████████████| 7.0 MB 10.0 MB/s
# Collecting typing==3.6.6
#   Downloading typing-3.6.6-py3-none-any.whl (25 kB)
# Collecting pandas==0.25.3
#   Downloading pandas-0.25.3-cp37-cp37m-manylinux1_x86_64.whl (10.4 MB)
#      |████████████████████████████████| 10.4 MB 22.7 MB/s
# Collecting mxnet==1.4.0
#   Downloading mxnet-1.4.0-py2.py3-none-manylinux1_x86_64.whl (29.6 MB)
#      |████████████████████████████████| 29.6 MB 36 kB/s
# Collecting numpy<1.15.0,>=1.8.2
#   Downloading numpy-1.14.6-cp37-cp37m-manylinux1_x86_64.whl (13.8 MB)
#      |████████████████████████████████| 13.8 MB 114 kB/s
# Requirement already satisfied: requests>=2.20.0 in /usr/local/lib/python3.7/dist-packages (from mxnet==1.4.0->datawig) (2.23.0)
# Collecting graphviz<0.9.0,>=0.8.1
#   Downloading graphviz-0.8.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas==0.25.3->datawig) (2018.9)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from pandas==0.25.3->datawig) (2.8.2)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn[alldeps]==0.22.1->datawig) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn[alldeps]==0.22.1->datawig) (1.0.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.6.1->pandas==0.25.3->datawig) (1.15.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20.0->mxnet==1.4.0->datawig) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20.0->mxnet==1.4.0->datawig) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20.0->mxnet==1.4.0->datawig) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20.0->mxnet==1.4.0->datawig) (2.10)
# Building wheels for collected packages: datawig
#   Building wheel for datawig (setup.py) ... done
#   Created wheel for datawig: filename=datawig-0.2.0-py3-none-any.whl size=72678 sha256=71af5b0969df834b2b146894d01b801d57a8483fc681720b9db37b5c2ebae5a3
#   Stored in directory: /root/.cache/pip/wheels/23/44/aa/12cf6e868f0d71e3c4e57796330094461ade4cb3f1a3acd6c4
# Successfully built datawig
# Installing collected packages: numpy, scikit-learn, graphviz, typing, pandas, mxnet, datawig
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.22.2.post1
#     Uninstalling scikit-learn-0.22.2.post1:
#       Successfully uninstalled scikit-learn-0.22.2.post1
#   Attempting uninstall: graphviz
#     Found existing installation: graphviz 0.10.1
#     Uninstalling graphviz-0.10.1:
#       Successfully uninstalled graphviz-0.10.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.1.5
#     Uninstalling pandas-1.1.5:
#       Successfully uninstalled pandas-1.1.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# xarray 0.18.2 requires numpy>=1.17, but you have numpy 1.14.6 which is incompatible.
# xarray 0.18.2 requires pandas>=1.0, but you have pandas 0.25.3 which is incompatible.
# tifffile 2021.8.8 requires numpy>=1.15.1, but you have numpy 1.14.6 which is incompatible.
# tensorflow 2.5.0 requires numpy~=1.19.2, but you have numpy 1.14.6 which is incompatible.
# spacy 2.2.4 requires numpy>=1.15.0, but you have numpy 1.14.6 which is incompatible.
# seaborn 0.11.1 requires numpy>=1.15, but you have numpy 1.14.6 which is incompatible.
# pymc3 3.11.2 requires numpy>=1.15.0, but you have numpy 1.14.6 which is incompatible.
# pyerfa 2.0.0 requires numpy>=1.17, but you have numpy 1.14.6 which is incompatible.
# pyarrow 3.0.0 requires numpy>=1.16.6, but you have numpy 1.14.6 which is incompatible.
# plotnine 0.6.0 requires numpy>=1.16.0, but you have numpy 1.14.6 which is incompatible.
# numba 0.51.2 requires numpy>=1.15, but you have numpy 1.14.6 which is incompatible.
# librosa 0.8.1 requires numpy>=1.15.0, but you have numpy 1.14.6 which is incompatible.
# kapre 0.3.5 requires numpy>=1.18.5, but you have numpy 1.14.6 which is incompatible.
# jaxlib 0.1.69+cuda110 requires numpy>=1.17, but you have numpy 1.14.6 which is incompatible.
# jax 0.2.17 requires numpy>=1.17, but you have numpy 1.14.6 which is incompatible.
# imgaug 0.2.9 requires numpy>=1.15.0, but you have numpy 1.14.6 which is incompatible.
# google-colab 1.0.0 requires pandas~=1.1.0; python_version >= "3.0", but you have pandas 0.25.3 which is incompatible.
# fbprophet 0.7.1 requires numpy>=1.15.4, but you have numpy 1.14.6 which is incompatible.
# fbprophet 0.7.1 requires pandas>=1.0.4, but you have pandas 0.25.3 which is incompatible.
# fastai 1.0.61 requires numpy>=1.15, but you have numpy 1.14.6 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# cvxpy 1.0.31 requires numpy>=1.15, but you have numpy 1.14.6 which is incompatible.
# cupy-cuda101 9.1.0 requires numpy>=1.17, but you have numpy 1.14.6 which is incompatible.
# blis 0.4.1 requires numpy>=1.15.0, but you have numpy 1.14.6 which is incompatible.
# astropy 4.3.1 requires numpy>=1.17, but you have numpy 1.14.6 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed datawig-0.2.0 graphviz-0.8.4 mxnet-1.4.0 numpy-1.14.6 pandas-0.25.3 scikit-learn-0.22.1 typing-3.6.6

# %%
import datawig

# %% [markdown]
# ##### Temperature Imputation

# %%
# Impute null Temperature data using datawig
from datawig import SimpleImputer

# Split data set
scale_data_train, scale_data_test = datawig.utils.random_split(scale_data, split_ratios=[0.8, 0.2])

# Initialize a simpleImputer model 
imputer = SimpleImputer(input_columns=['Well No', 'P', 'XCO2', 'pH', 'Ca2+', 'Na+', 'Mg2+', 'Fe2+',
       'HCO3-', 'SO4 2-', 'Cl-', 'CO3 2-', 'TDS', 'Scale Type'], output_column='T', output_path = 'imputer_model')

imputer.fit(train_df=scale_data_train)


scale_data_test_imputed = imputer.predict(scale_data_test)

# %%
# Predict null T values
imputer.fit(scale_data)

scale_imputed_data = imputer.predict(scale_data)
# Out:
# WARNING:root:Already bound, ignoring bind()
# /usr/local/lib/python3.7/dist-packages/mxnet/module/base_module.py:503: UserWarning: Parameters already initialized and force_init=False. init_params call ignored.
#   allow_missing=allow_missing, force_init=force_init)
# WARNING:root:optimizer already initialized, ignoring...
# INFO:root:Epoch[0] Batch [0-1]	Speed: 1171.72 samples/sec	cross-entropy=76.043877	T-accuracy=0.000000
# INFO:root:Epoch[0] Train-cross-entropy=76.043877
# INFO:root:Epoch[0] Train-T-accuracy=0.000000
# INFO:root:Epoch[0] Time cost=0.036
# INFO:root:Saved checkpoint to "imputer_model/model-0000.params"
# INFO:root:Epoch[0] Validation-cross-entropy=195.382355
# INFO:root:Epoch[0] Validation-T-accuracy=0.000000
# INFO:root:Epoch[1] Batch [0-1]	Speed: 1144.62 samples/sec	cross-entropy=59.731262	T-accuracy=0.000000
# INFO:root:Epoch[1] Train-cross-entropy=59.731262
# INFO:root:Epoch[1] Train-T-accuracy=0.000000
# INFO:root:Epoch[1] Time cost=0.034
# INFO:root:Saved checkpoint to "imputer_model/model-0001.params"
# INFO:root:Epoch[1] Validation-cross-entropy=140.444397
# INFO:root:Epoch[1] Validation-T-accuracy=0.000000
# INFO:root:Epoch[2] Batch [0-1]	Speed: 1164.13 samples/sec	cross-entropy=48.449057	T-accuracy=0.000000
# INFO:root:Epoch[2] Train-cross-entropy=48.449057
# INFO:root:Epoch[2] Train-T-accuracy=0.000000
# INFO:root:Epoch[2] Time cost=0.034
# INFO:root:Saved checkpoint to "imputer_model/model-0002.params"
# INFO:root:Epoch[2] Validation-cross-entropy=97.593697
# INFO:root:Epoch[2] Validation-T-accuracy=0.000000
# INFO:root:Epoch[3] Batch [0-1]	Speed: 1129.04 samples/sec	cross-entropy=44.618540	T-accuracy=0.000000
# INFO:root:Epoch[3] Train-cross-entropy=44.618540
# INFO:root:Epoch[3] Train-T-accuracy=0.000000
# INFO:root:Epoch[3] Time cost=0.034
# INFO:root:Saved checkpoint to "imputer_model/model-0003.params"
# INFO:root:Epoch[3] Validation-cross-entropy=71.130608
# INFO:root:Epoch[3] Validation-T-accuracy=0.000000
# INFO:root:Epoch[4] Batch [0-1]	Speed: 1145.50 samples/sec	cross-entropy=41.639928	T-accuracy=0.000000
# INFO:root:Epoch[4] Train-cross-entropy=41.639928
# INFO:root:Epoch[4] Train-T-accuracy=0.000000
# INFO:root:Epoch[4] Time cost=0.034
# INFO:root:Saved checkpoint to "imputer_model/model-0004.params"
# INFO:root:Epoch[4] Validation-cross-entropy=55.818447
# INFO:root:Epoch[4] Validation-T-accuracy=0.000000
# INFO:root:Epoch[5] Batch [0-1]	Speed: 1092.04 samples/sec	cross-entropy=36.162576	T-accuracy=0.000000
# INFO:root:Epoch[5] Train-cross-entropy=36.162576
# INFO:root:Epoch[5] Train-T-accuracy=0.000000
# INFO:root:Epoch[5] Time cost=0.036
# INFO:root:Saved checkpoint to "imputer_model/model-0005.params"
# INFO:root:Epoch[5] Validation-cross-entropy=48.712341
# INFO:root:Epoch[5] Validation-T-accuracy=0.000000
# INFO:root:Epoch[6] Batch [0-1]	Speed: 1114.58 samples/sec	cross-entropy=30.415955	T-accuracy=0.000000
# INFO:root:Epoch[6] Train-cross-entropy=30.415955
# INFO:root:Epoch[6] Train-T-accuracy=0.000000
# INFO:root:Epoch[6] Time cost=0.036
# INFO:root:Saved checkpoint to "imputer_model/model-0006.params"
# INFO:root:Epoch[6] Validation-cross-entropy=48.081657
# INFO:root:Epoch[6] Validation-T-accuracy=0.000000
# INFO:root:Epoch[7] Batch [0-1]	Speed: 1092.02 samples/sec	cross-entropy=26.369298	T-accuracy=0.000000
# INFO:root:Epoch[7] Train-cross-entropy=26.369298
# INFO:root:Epoch[7] Train-T-accuracy=0.000000
# INFO:root:Epoch[7] Time cost=0.036
# INFO:root:Saved checkpoint to "imputer_model/model-0007.params"
# INFO:root:Epoch[7] Validation-cross-entropy=49.952312
# INFO:root:Epoch[7] Validation-T-accuracy=0.000000
# INFO:root:Epoch[8] Batch [0-1]	Speed: 1095.55 samples/sec	cross-entropy=23.872191	T-accuracy=0.000000
# INFO:root:Epoch[8] Train-cross-entropy=23.872191
# INFO:root:Epoch[8] Train-T-accuracy=0.000000
# INFO:root:Epoch[8] Time cost=0.037
# INFO:root:Saved checkpoint to "imputer_model/model-0008.params"
# INFO:root:Epoch[8] Validation-cross-entropy=48.507626
# INFO:root:Epoch[8] Validation-T-accuracy=0.000000
# INFO:root:Epoch[9] Batch [0-1]	Speed: 1134.53 samples/sec	cross-entropy=21.739265	T-accuracy=0.000000
# INFO:root:Epoch[9] Train-cross-entropy=21.739265
# INFO:root:Epoch[9] Train-T-accuracy=0.000000
# INFO:root:Epoch[9] Time cost=0.035
# INFO:root:Saved checkpoint to "imputer_model/model-0009.params"
# INFO:root:Epoch[9] Validation-cross-entropy=41.389019
# INFO:root:Epoch[9] Validation-T-accuracy=0.000000
# INFO:root:Epoch[10] Batch [0-1]	Speed: 1197.09 samples/sec	cross-entropy=19.267499	T-accuracy=0.000000
# INFO:root:Epoch[10] Train-cross-entropy=19.267499
# INFO:root:Epoch[10] Train-T-accuracy=0.000000
# INFO:root:Epoch[10] Time cost=0.032
# INFO:root:Saved checkpoint to "imputer_model/model-0010.params"
# INFO:root:Epoch[10] Validation-cross-entropy=32.863628
# INFO:root:Epoch[10] Validation-T-accuracy=0.000000
# INFO:root:Epoch[11] Batch [0-1]	Speed: 1210.00 samples/sec	cross-entropy=17.037418	T-accuracy=0.000000
# INFO:root:Epoch[11] Train-cross-entropy=17.037418
# INFO:root:Epoch[11] Train-T-accuracy=0.000000
# INFO:root:Epoch[11] Time cost=0.035
# INFO:root:Saved checkpoint to "imputer_model/model-0011.params"
# INFO:root:Epoch[11] Validation-cross-entropy=25.431992
# INFO:root:Epoch[11] Validation-T-accuracy=0.000000
# INFO:root:Epoch[12] Batch [0-1]	Speed: 1176.32 samples/sec	cross-entropy=15.553603	T-accuracy=0.000000
# INFO:root:Epoch[12] Train-cross-entropy=15.553603
# INFO:root:Epoch[12] Train-T-accuracy=0.000000
# INFO:root:Epoch[12] Time cost=0.033
# INFO:root:Saved checkpoint to "imputer_model/model-0012.params"
# INFO:root:Epoch[12] Validation-cross-entropy=19.602997
# INFO:root:Epoch[12] Validation-T-accuracy=0.000000
# INFO:root:Epoch[13] Batch [0-1]	Speed: 1190.63 samples/sec	cross-entropy=14.323629	T-accuracy=0.000000
# INFO:root:Epoch[13] Train-cross-entropy=14.323629
# INFO:root:Epoch[13] Train-T-accuracy=0.000000
# INFO:root:Epoch[13] Time cost=0.034
# INFO:root:Saved checkpoint to "imputer_model/model-0013.params"
# INFO:root:Epoch[13] Validation-cross-entropy=16.114901
# INFO:root:Epoch[13] Validation-T-accuracy=0.000000
# INFO:root:Epoch[14] Batch [0-1]	Speed: 1192.35 samples/sec	cross-entropy=13.068628	T-accuracy=0.000000
# INFO:root:Epoch[14] Train-cross-entropy=13.068628
# INFO:root:Epoch[14] Train-T-accuracy=0.000000
# INFO:root:Epoch[14] Time cost=0.033
# INFO:root:Saved checkpoint to "imputer_model/model-0014.params"
# INFO:root:Epoch[14] Validation-cross-entropy=15.010943
# INFO:root:Epoch[14] Validation-T-accuracy=0.000000
# INFO:root:Epoch[15] Batch [0-1]	Speed: 1164.96 samples/sec	cross-entropy=11.931646	T-accuracy=0.000000
# INFO:root:Epoch[15] Train-cross-entropy=11.931646
# INFO:root:Epoch[15] Train-T-accuracy=0.000000
# INFO:root:Epoch[15] Time cost=0.036
# INFO:root:Saved checkpoint to "imputer_model/model-0015.params"
# INFO:root:Epoch[15] Validation-cross-entropy=15.282028
# INFO:root:Epoch[15] Validation-T-accuracy=0.000000
# INFO:root:Epoch[16] Batch [0-1]	Speed: 1194.28 samples/sec	cross-entropy=11.003403	T-accuracy=0.000000
# INFO:root:Epoch[16] Train-cross-entropy=11.003403
# INFO:root:Epoch[16] Train-T-accuracy=0.000000
# INFO:root:Epoch[16] Time cost=0.033
# INFO:root:Saved checkpoint to "imputer_model/model-0016.params"
# INFO:root:Epoch[16] Validation-cross-entropy=16.164955
# INFO:root:Epoch[16] Validation-T-accuracy=0.000000
# INFO:root:Epoch[17] Batch [0-1]	Speed: 1203.38 samples/sec	cross-entropy=10.327929	T-accuracy=0.000000
# INFO:root:Epoch[17] Train-cross-entropy=10.327929
# INFO:root:Epoch[17] Train-T-accuracy=0.000000
# INFO:root:Epoch[17] Time cost=0.033
# INFO:root:Saved checkpoint to "imputer_model/model-0017.params"
# INFO:root:Epoch[17] Validation-cross-entropy=17.363497
# INFO:root:Epoch[17] Validation-T-accuracy=0.000000
# INFO:root:Epoch[18] Batch [0-1]	Speed: 1145.18 samples/sec	cross-entropy=9.739029	T-accuracy=0.000000
# INFO:root:Epoch[18] Train-cross-entropy=9.739029
# INFO:root:Epoch[18] Train-T-accuracy=0.000000
# INFO:root:Epoch[18] Time cost=0.034
# INFO:root:Saved checkpoint to "imputer_model/model-0018.params"
# INFO:root:Epoch[18] Validation-cross-entropy=18.598303
# INFO:root:Epoch[18] Validation-T-accuracy=0.000000
# INFO:root:Epoch[19] Batch [0-1]	Speed: 1148.26 samples/sec	cross-entropy=9.026429	T-accuracy=0.000000
# INFO:root:Epoch[19] Train-cross-entropy=9.026429
# INFO:root:Epoch[19] Train-T-accuracy=0.000000
# INFO:root:Epoch[19] Time cost=0.040
# INFO:root:Saved checkpoint to "imputer_model/model-0019.params"
# INFO:root:No improvement detected for 5 epochs compared to 15.010943412780762 last error obtained: 19.503541946411133, stopping here
# INFO:root:
# ========== done (1.2243928909301758 s) fit model

# %%
# Check if values were imputed
scale_imputed_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541 entries, 0 to 540
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Well No            541 non-null    int64
#  1   T                  36 non-null     float64
#  2   P                  36 non-null     float64
#  3   XCO2               31 non-null     float64
#  4   pH                 535 non-null    float64
#  5   Ca2+               541 non-null    float64
#  6   Na+                540 non-null    float64
#  7   Mg2+               540 non-null    float64
#  8   Fe2+               30 non-null     float64
#  9   HCO3-              541 non-null    float64
#  10  SO4 2-             539 non-null    float64
#  11  Cl-                35 non-null     float64
#  12  CO3 2-             30 non-null     float64
#  13  TDS                510 non-null    float64
#  14  Inspection Result  541 non-null    int64
#  15  Scale Type         540 non-null    object
#  16  T_imputed          541 non-null    float64
# dtypes: float64(14), int64(2), object(1)
# memory usage: 72.0+ KB

# %%
T_imputed = scale_imputed_data['T_imputed']

# %%
# Get Imputed datas samples
scale_data_test_imputed.sample(6, random_state=20)
# Out:
#      Well No   T   P  XCO2  ...      TDS  Inspection Result  Scale Type   T_imputed
# 313       94 NaN NaN   NaN  ...  30782.0                  1       CaCO3  121.171964
# 165       58 NaN NaN   NaN  ...  65618.0                  1       CaCO3  122.858006
# 430      113 NaN NaN   NaN  ...  52058.0                  0       CaCO3  122.805193
# 484      119 NaN NaN   NaN  ...  83278.0                  0       CaCO3  125.179167
# 491      120 NaN NaN   NaN  ...  35671.0                  0       CaCO3  124.966166
# 364      101 NaN NaN   NaN  ...  29037.0                  1       CaCO3  122.656907
#
# [6 rows x 17 columns]

# %%
# Using rsquare metrics check the performance of the imputer
# Score the model on the training set, round off the score to 2 decimal places, multiply 100 to get a percentage score
    

# Score the model on the test set, round off the score to 2 decimal places, multiply 100 to get a percentage score
from sklearn.metrics import r2_score

print("The test score for this model is {}".format((r2_score(scale_data_test['T'].dropna(), scale_data_test_imputed['T_imputed'])* 100).round(2) ) + "%")

# Imputer model evaluation
imputed_dw = scale_data_test_imputed[['T', 'T_imputed']]

from sklearn.metrics import  mean_squared_error as mse

dw_rmse = (mse(imputed_dw['T'], imputed_dw['T_imputed']))**0.5

# %% [markdown]
# ##### Pressure null data imputation

# %%
# Impute null Pressure data using datawig
from datawig import SimpleImputer

# Initialize a simpleImputer model 
imputer = SimpleImputer(input_columns=['Well No', 'T', 'XCO2', 'pH', 'Ca2+', 'Na+', 'Mg2+', 'Fe2+',
       'HCO3-', 'SO4 2-', 'Cl-', 'CO3 2-', 'TDS', 'Scale Type'], output_column='P', output_path = 'imputer_model')

imputer.fit(train_df=scale_data_train)


scale_data_test_imputed = imputer.predict(scale_data_test)

# %%
# Predict null P values
imputer.fit(scale_imputed_data)

scale_imputed_data = imputer.predict(scale_data)
# Out:
# WARNING:root:Already bound, ignoring bind()
# /usr/local/lib/python3.7/dist-packages/mxnet/module/base_module.py:503: UserWarning: Parameters already initialized and force_init=False. init_params call ignored.
#   allow_missing=allow_missing, force_init=force_init)
# WARNING:root:optimizer already initialized, ignoring...
# INFO:root:Epoch[0] Batch [0-1]	Speed: 1171.31 samples/sec	cross-entropy=198.807663	P-accuracy=0.000000
# INFO:root:Epoch[0] Train-cross-entropy=198.807663
# INFO:root:Epoch[0] Train-P-accuracy=0.000000
# INFO:root:Epoch[0] Time cost=0.038
# INFO:root:Saved checkpoint to "imputer_model/model-0000.params"
# INFO:root:Epoch[0] Validation-cross-entropy=114.384552
# INFO:root:Epoch[0] Validation-P-accuracy=0.000000
# INFO:root:Epoch[1] Batch [0-1]	Speed: 1144.97 samples/sec	cross-entropy=165.091370	P-accuracy=0.000000
# INFO:root:Epoch[1] Train-cross-entropy=165.091370
# INFO:root:Epoch[1] Train-P-accuracy=0.000000
# INFO:root:Epoch[1] Time cost=0.036
# INFO:root:Saved checkpoint to "imputer_model/model-0001.params"
# INFO:root:Epoch[1] Validation-cross-entropy=101.837341
# INFO:root:Epoch[1] Validation-P-accuracy=0.000000
# INFO:root:Epoch[2] Batch [0-1]	Speed: 1168.13 samples/sec	cross-entropy=138.513145	P-accuracy=0.000000
# INFO:root:Epoch[2] Train-cross-entropy=138.513145
# INFO:root:Epoch[2] Train-P-accuracy=0.000000
# INFO:root:Epoch[2] Time cost=0.034
# INFO:root:Saved checkpoint to "imputer_model/model-0002.params"
# INFO:root:Epoch[2] Validation-cross-entropy=84.564857
# INFO:root:Epoch[2] Validation-P-accuracy=0.000000
# INFO:root:Epoch[3] Batch [0-1]	Speed: 1165.29 samples/sec	cross-entropy=120.637997	P-accuracy=0.000000
# INFO:root:Epoch[3] Train-cross-entropy=120.637997
# INFO:root:Epoch[3] Train-P-accuracy=0.000000
# INFO:root:Epoch[3] Time cost=0.033
# INFO:root:Saved checkpoint to "imputer_model/model-0003.params"
# INFO:root:Epoch[3] Validation-cross-entropy=73.751831
# INFO:root:Epoch[3] Validation-P-accuracy=0.000000
# INFO:root:Epoch[4] Batch [0-1]	Speed: 1165.59 samples/sec	cross-entropy=105.192150	P-accuracy=0.000000
# INFO:root:Epoch[4] Train-cross-entropy=105.192150
# INFO:root:Epoch[4] Train-P-accuracy=0.000000
# INFO:root:Epoch[4] Time cost=0.034
# INFO:root:Saved checkpoint to "imputer_model/model-0004.params"
# INFO:root:Epoch[4] Validation-cross-entropy=68.374237
# INFO:root:Epoch[4] Validation-P-accuracy=0.000000
# INFO:root:Epoch[5] Batch [0-1]	Speed: 1178.49 samples/sec	cross-entropy=89.288582	P-accuracy=0.000000
# INFO:root:Epoch[5] Train-cross-entropy=89.288582
# INFO:root:Epoch[5] Train-P-accuracy=0.000000
# INFO:root:Epoch[5] Time cost=0.033
# INFO:root:Saved checkpoint to "imputer_model/model-0005.params"
# INFO:root:Epoch[5] Validation-cross-entropy=61.557629
# INFO:root:Epoch[5] Validation-P-accuracy=0.000000
# INFO:root:Epoch[6] Batch [0-1]	Speed: 1131.40 samples/sec	cross-entropy=79.048277	P-accuracy=0.000000
# INFO:root:Epoch[6] Train-cross-entropy=79.048277
# INFO:root:Epoch[6] Train-P-accuracy=0.000000
# INFO:root:Epoch[6] Time cost=0.035
# INFO:root:Saved checkpoint to "imputer_model/model-0006.params"
# INFO:root:Epoch[6] Validation-cross-entropy=52.595783
# INFO:root:Epoch[6] Validation-P-accuracy=0.000000
# INFO:root:Epoch[7] Batch [0-1]	Speed: 1143.12 samples/sec	cross-entropy=71.486599	P-accuracy=0.000000
# INFO:root:Epoch[7] Train-cross-entropy=71.486599
# INFO:root:Epoch[7] Train-P-accuracy=0.000000
# INFO:root:Epoch[7] Time cost=0.035
# INFO:root:Saved checkpoint to "imputer_model/model-0007.params"
# INFO:root:Epoch[7] Validation-cross-entropy=48.102379
# INFO:root:Epoch[7] Validation-P-accuracy=0.000000
# INFO:root:Epoch[8] Batch [0-1]	Speed: 998.88 samples/sec	cross-entropy=65.246862	P-accuracy=0.000000
# INFO:root:Epoch[8] Train-cross-entropy=65.246862
# INFO:root:Epoch[8] Train-P-accuracy=0.000000
# INFO:root:Epoch[8] Time cost=0.036
# INFO:root:Saved checkpoint to "imputer_model/model-0008.params"
# INFO:root:Epoch[8] Validation-cross-entropy=55.230721
# INFO:root:Epoch[8] Validation-P-accuracy=0.000000
# INFO:root:Epoch[9] Batch [0-1]	Speed: 1189.14 samples/sec	cross-entropy=58.934508	P-accuracy=0.000000
# INFO:root:Epoch[9] Train-cross-entropy=58.934508
# INFO:root:Epoch[9] Train-P-accuracy=0.000000
# INFO:root:Epoch[9] Time cost=0.036
# INFO:root:Saved checkpoint to "imputer_model/model-0009.params"
# INFO:root:Epoch[9] Validation-cross-entropy=73.720406
# INFO:root:Epoch[9] Validation-P-accuracy=0.000000
# INFO:root:Epoch[10] Batch [0-1]	Speed: 1187.81 samples/sec	cross-entropy=53.163478	P-accuracy=0.000000
# INFO:root:Epoch[10] Train-cross-entropy=53.163478
# INFO:root:Epoch[10] Train-P-accuracy=0.000000
# INFO:root:Epoch[10] Time cost=0.033
# INFO:root:Saved checkpoint to "imputer_model/model-0010.params"
# INFO:root:Epoch[10] Validation-cross-entropy=92.559120
# INFO:root:Epoch[10] Validation-P-accuracy=0.000000
# INFO:root:Epoch[11] Batch [0-1]	Speed: 1173.64 samples/sec	cross-entropy=50.567088	P-accuracy=0.000000
# INFO:root:Epoch[11] Train-cross-entropy=50.567088
# INFO:root:Epoch[11] Train-P-accuracy=0.000000
# INFO:root:Epoch[11] Time cost=0.033
# INFO:root:Saved checkpoint to "imputer_model/model-0011.params"
# INFO:root:No improvement detected for 5 epochs compared to 52.59578323364258 last error obtained: 101.99512481689453, stopping here
# INFO:root:
# ========== done (0.7218167781829834 s) fit model

# %%
# Check if values were imputed
scale_imputed_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541 entries, 0 to 540
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Well No            541 non-null    int64
#  1   T                  36 non-null     float64
#  2   P                  36 non-null     float64
#  3   XCO2               31 non-null     float64
#  4   pH                 535 non-null    float64
#  5   Ca2+               541 non-null    float64
#  6   Na+                540 non-null    float64
#  7   Mg2+               540 non-null    float64
#  8   Fe2+               30 non-null     float64
#  9   HCO3-              541 non-null    float64
#  10  SO4 2-             539 non-null    float64
#  11  Cl-                35 non-null     float64
#  12  CO3 2-             30 non-null     float64
#  13  TDS                510 non-null    float64
#  14  Inspection Result  541 non-null    int64
#  15  Scale Type         540 non-null    object
#  16  P_imputed          541 non-null    float64
# dtypes: float64(14), int64(2), object(1)
# memory usage: 72.0+ KB

# %%
P_imputed = scale_imputed_data['P_imputed']

# %% [markdown]
# ##### CO2 mole fraction (XCO2) null data imputation

# %%
# Impute null XCO2 data using datawig
from datawig import SimpleImputer

# Initialize a simpleImputer model 
imputer = SimpleImputer(input_columns=['Well No', 'T', 'P', 'pH', 'Ca2+', 'Na+', 'Mg2+', 'Fe2+',
       'HCO3-', 'SO4 2-', 'Cl-', 'CO3 2-', 'TDS', 'Scale Type'], output_column='XCO2', output_path = 'imputer_model')

imputer.fit(train_df=scale_data_train)


scale_data_test_imputed = imputer.predict(scale_data_test)

# %%
# Predict null XCO2 values
imputer.fit(scale_imputed_data)

scale_imputed_data = imputer.predict(scale_data)
# Out:
# WARNING:root:Already bound, ignoring bind()
# /usr/local/lib/python3.7/dist-packages/mxnet/module/base_module.py:503: UserWarning: Parameters already initialized and force_init=False. init_params call ignored.
#   allow_missing=allow_missing, force_init=force_init)
# WARNING:root:optimizer already initialized, ignoring...
# INFO:root:Epoch[0] Batch [0-1]	Speed: 1143.54 samples/sec	cross-entropy=302.138491	XCO2-accuracy=0.000000
# INFO:root:Epoch[0] Train-cross-entropy=302.138491
# INFO:root:Epoch[0] Train-XCO2-accuracy=0.000000
# INFO:root:Epoch[0] Time cost=0.039
# INFO:root:Saved checkpoint to "imputer_model/model-0000.params"
# INFO:root:Epoch[0] Validation-cross-entropy=13.560953
# INFO:root:Epoch[0] Validation-XCO2-accuracy=0.000000
# INFO:root:Epoch[1] Batch [0-1]	Speed: 1127.88 samples/sec	cross-entropy=292.266296	XCO2-accuracy=0.000000
# INFO:root:Epoch[1] Train-cross-entropy=292.266296
# INFO:root:Epoch[1] Train-XCO2-accuracy=0.000000
# INFO:root:Epoch[1] Time cost=0.037
# INFO:root:Saved checkpoint to "imputer_model/model-0001.params"
# INFO:root:Epoch[1] Validation-cross-entropy=14.816266
# INFO:root:Epoch[1] Validation-XCO2-accuracy=0.000000
# INFO:root:Epoch[2] Batch [0-1]	Speed: 945.01 samples/sec	cross-entropy=283.978329	XCO2-accuracy=0.000000
# INFO:root:Epoch[2] Train-cross-entropy=283.978329
# INFO:root:Epoch[2] Train-XCO2-accuracy=0.000000
# INFO:root:Epoch[2] Time cost=0.040
# INFO:root:Saved checkpoint to "imputer_model/model-0002.params"
# INFO:root:Epoch[2] Validation-cross-entropy=19.335014
# INFO:root:Epoch[2] Validation-XCO2-accuracy=0.000000
# INFO:root:Epoch[3] Batch [0-1]	Speed: 1109.79 samples/sec	cross-entropy=276.614426	XCO2-accuracy=0.000000
# INFO:root:Epoch[3] Train-cross-entropy=276.614426
# INFO:root:Epoch[3] Train-XCO2-accuracy=0.000000
# INFO:root:Epoch[3] Time cost=0.036
# INFO:root:Saved checkpoint to "imputer_model/model-0003.params"
# INFO:root:Epoch[3] Validation-cross-entropy=19.781376
# INFO:root:Epoch[3] Validation-XCO2-accuracy=0.000000
# INFO:root:Epoch[4] Batch [0-1]	Speed: 1032.22 samples/sec	cross-entropy=270.684708	XCO2-accuracy=0.000000
# INFO:root:Epoch[4] Train-cross-entropy=270.684708
# INFO:root:Epoch[4] Train-XCO2-accuracy=0.000000
# INFO:root:Epoch[4] Time cost=0.038
# INFO:root:Saved checkpoint to "imputer_model/model-0004.params"
# INFO:root:Epoch[4] Validation-cross-entropy=17.135368
# INFO:root:Epoch[4] Validation-XCO2-accuracy=0.000000
# INFO:root:Epoch[5] Batch [0-1]	Speed: 1077.66 samples/sec	cross-entropy=266.364109	XCO2-accuracy=0.000000
# INFO:root:Epoch[5] Train-cross-entropy=266.364109
# INFO:root:Epoch[5] Train-XCO2-accuracy=0.000000
# INFO:root:Epoch[5] Time cost=0.035
# INFO:root:Saved checkpoint to "imputer_model/model-0005.params"
# INFO:root:No improvement detected for 5 epochs compared to 13.560953140258789 last error obtained: 14.37759780883789, stopping here
# INFO:root:
# ========== done (0.40153050422668457 s) fit model

# %%
XCO2_imputed = scale_imputed_data['XCO2_imputed']

# %% [markdown]
# ##### pH null data imputation

# %%
# Impute null pH data using datawig
from datawig import SimpleImputer

# Initialize a simpleImputer model 
imputer = SimpleImputer(input_columns=['Well No', 'T', 'XCO2', 'P', 'Ca2+', 'Na+', 'Mg2+', 'Fe2+',
       'HCO3-', 'SO4 2-', 'Cl-', 'CO3 2-', 'TDS', 'Scale Type'], output_column='pH', output_path = 'imputer_model')

imputer.fit(train_df=scale_data_train)


scale_data_test_imputed = imputer.predict(scale_data_test)

# %%
# Predict null pH values
imputer.fit(scale_imputed_data)

scale_imputed_data = imputer.predict(scale_data)
# Out:
# WARNING:root:Already bound, ignoring bind()
# /usr/local/lib/python3.7/dist-packages/mxnet/module/base_module.py:503: UserWarning: Parameters already initialized and force_init=False. init_params call ignored.
#   allow_missing=allow_missing, force_init=force_init)
# WARNING:root:optimizer already initialized, ignoring...
# INFO:root:Epoch[0] Batch [0-16]	Speed: 1135.26 samples/sec	cross-entropy=7.916704	pH-accuracy=0.000000
# INFO:root:Epoch[0] Train-cross-entropy=7.498191
# INFO:root:Epoch[0] Train-pH-accuracy=0.000000
# INFO:root:Epoch[0] Time cost=0.441
# INFO:root:Saved checkpoint to "imputer_model/model-0000.params"
# INFO:root:Epoch[0] Validation-cross-entropy=8.416661
# INFO:root:Epoch[0] Validation-pH-accuracy=0.000000
# INFO:root:Epoch[1] Batch [0-16]	Speed: 1155.70 samples/sec	cross-entropy=7.432952	pH-accuracy=0.000000
# INFO:root:Epoch[1] Train-cross-entropy=7.147478
# INFO:root:Epoch[1] Train-pH-accuracy=0.000000
# INFO:root:Epoch[1] Time cost=0.441
# INFO:root:Saved checkpoint to "imputer_model/model-0001.params"
# INFO:root:Epoch[1] Validation-cross-entropy=8.430323
# INFO:root:Epoch[1] Validation-pH-accuracy=0.000000
# INFO:root:Epoch[2] Batch [0-16]	Speed: 1151.23 samples/sec	cross-entropy=7.343953	pH-accuracy=0.000000
# INFO:root:Epoch[2] Train-cross-entropy=6.952544
# INFO:root:Epoch[2] Train-pH-accuracy=0.000000
# INFO:root:Epoch[2] Time cost=0.437
# INFO:root:Saved checkpoint to "imputer_model/model-0002.params"
# INFO:root:Epoch[2] Validation-cross-entropy=8.276631
# INFO:root:Epoch[2] Validation-pH-accuracy=0.000000
# INFO:root:Epoch[3] Batch [0-16]	Speed: 1177.09 samples/sec	cross-entropy=7.292863	pH-accuracy=0.000000
# INFO:root:Epoch[3] Train-cross-entropy=6.875705
# INFO:root:Epoch[3] Train-pH-accuracy=0.000000
# INFO:root:Epoch[3] Time cost=0.434
# INFO:root:Saved checkpoint to "imputer_model/model-0003.params"
# INFO:root:Epoch[3] Validation-cross-entropy=8.443729
# INFO:root:Epoch[3] Validation-pH-accuracy=0.000000
# INFO:root:Epoch[4] Batch [0-16]	Speed: 1099.89 samples/sec	cross-entropy=7.191403	pH-accuracy=0.000000
# INFO:root:Epoch[4] Train-cross-entropy=6.775803
# INFO:root:Epoch[4] Train-pH-accuracy=0.000000
# INFO:root:Epoch[4] Time cost=0.451
# INFO:root:Saved checkpoint to "imputer_model/model-0004.params"
# INFO:root:Epoch[4] Validation-cross-entropy=8.400510
# INFO:root:Epoch[4] Validation-pH-accuracy=0.000000
# INFO:root:Epoch[5] Batch [0-16]	Speed: 1169.51 samples/sec	cross-entropy=7.164931	pH-accuracy=0.000000
# INFO:root:Epoch[5] Train-cross-entropy=6.726288
# INFO:root:Epoch[5] Train-pH-accuracy=0.000000
# INFO:root:Epoch[5] Time cost=0.440
# INFO:root:Saved checkpoint to "imputer_model/model-0005.params"
# INFO:root:Epoch[5] Validation-cross-entropy=8.439281
# INFO:root:Epoch[5] Validation-pH-accuracy=0.000000
# INFO:root:Epoch[6] Batch [0-16]	Speed: 1147.89 samples/sec	cross-entropy=7.092976	pH-accuracy=0.000000
# INFO:root:Epoch[6] Train-cross-entropy=6.658232
# INFO:root:Epoch[6] Train-pH-accuracy=0.000000
# INFO:root:Epoch[6] Time cost=0.438
# INFO:root:Saved checkpoint to "imputer_model/model-0006.params"
# INFO:root:Epoch[6] Validation-cross-entropy=8.429618
# INFO:root:Epoch[6] Validation-pH-accuracy=0.000000
# INFO:root:Epoch[7] Batch [0-16]	Speed: 1171.99 samples/sec	cross-entropy=7.080297	pH-accuracy=0.000000
# INFO:root:Epoch[7] Train-cross-entropy=6.624310
# INFO:root:Epoch[7] Train-pH-accuracy=0.000000
# INFO:root:Epoch[7] Time cost=0.432
# INFO:root:Saved checkpoint to "imputer_model/model-0007.params"
# INFO:root:No improvement detected for 5 epochs compared to 8.276630520820618 last error obtained: 8.519691944122314, stopping here
# INFO:root:
# ========== done (4.020124912261963 s) fit model

# %%
pH_imputed = scale_imputed_data['pH_imputed']

# %% [markdown]
# ##### Fe2+ null data imputation

# %%
# Impute null Fe2+ data using datawig
from datawig import SimpleImputer

# Initialize a simpleImputer model 
imputer = SimpleImputer(input_columns=['Well No', 'T', 'XCO2', 'P', 'Ca2+', 'Na+', 'Mg2+', 'pH',
       'HCO3-', 'SO4 2-', 'Cl-', 'CO3 2-', 'TDS', 'Scale Type'], output_column='Fe2+', output_path = 'imputer_model')

imputer.fit(train_df=scale_data_train)


scale_data_test_imputed = imputer.predict(scale_data_test)

# %%
# Predict null Fe2+ values
imputer.fit(scale_imputed_data)

scale_imputed_data = imputer.predict(scale_data)
# Out:
# WARNING:root:Already bound, ignoring bind()
# /usr/local/lib/python3.7/dist-packages/mxnet/module/base_module.py:503: UserWarning: Parameters already initialized and force_init=False. init_params call ignored.
#   allow_missing=allow_missing, force_init=force_init)
# WARNING:root:optimizer already initialized, ignoring...
# INFO:root:Epoch[0] Batch [0-1]	Speed: 1171.53 samples/sec	cross-entropy=61.787258	Fe2+-accuracy=0.000000
# INFO:root:Epoch[0] Train-cross-entropy=61.787258
# INFO:root:Epoch[0] Train-Fe2+-accuracy=0.000000
# INFO:root:Epoch[0] Time cost=0.035
# INFO:root:Saved checkpoint to "imputer_model/model-0000.params"
# INFO:root:Epoch[0] Validation-cross-entropy=113.784447
# INFO:root:Epoch[0] Validation-Fe2+-accuracy=0.000000
# INFO:root:Epoch[1] Batch [0-1]	Speed: 1030.83 samples/sec	cross-entropy=31.589330	Fe2+-accuracy=0.000000
# INFO:root:Epoch[1] Train-cross-entropy=31.589330
# INFO:root:Epoch[1] Train-Fe2+-accuracy=0.000000
# INFO:root:Epoch[1] Time cost=0.038
# INFO:root:Saved checkpoint to "imputer_model/model-0001.params"
# INFO:root:Epoch[1] Validation-cross-entropy=66.572685
# INFO:root:Epoch[1] Validation-Fe2+-accuracy=0.000000
# INFO:root:Epoch[2] Batch [0-1]	Speed: 1076.41 samples/sec	cross-entropy=30.960925	Fe2+-accuracy=0.000000
# INFO:root:Epoch[2] Train-cross-entropy=30.960925
# INFO:root:Epoch[2] Train-Fe2+-accuracy=0.000000
# INFO:root:Epoch[2] Time cost=0.042
# INFO:root:Saved checkpoint to "imputer_model/model-0002.params"
# INFO:root:Epoch[2] Validation-cross-entropy=63.228821
# INFO:root:Epoch[2] Validation-Fe2+-accuracy=0.000000
# INFO:root:Epoch[3] Batch [0-1]	Speed: 1024.84 samples/sec	cross-entropy=31.348081	Fe2+-accuracy=0.000000
# INFO:root:Epoch[3] Train-cross-entropy=31.348081
# INFO:root:Epoch[3] Train-Fe2+-accuracy=0.000000
# INFO:root:Epoch[3] Time cost=0.039
# INFO:root:Saved checkpoint to "imputer_model/model-0003.params"
# INFO:root:Epoch[3] Validation-cross-entropy=70.774048
# INFO:root:Epoch[3] Validation-Fe2+-accuracy=0.000000
# INFO:root:Epoch[4] Batch [0-1]	Speed: 1121.62 samples/sec	cross-entropy=27.520256	Fe2+-accuracy=0.000000
# INFO:root:Epoch[4] Train-cross-entropy=27.520256
# INFO:root:Epoch[4] Train-Fe2+-accuracy=0.000000
# INFO:root:Epoch[4] Time cost=0.034
# INFO:root:Saved checkpoint to "imputer_model/model-0004.params"
# INFO:root:Epoch[4] Validation-cross-entropy=73.794662
# INFO:root:Epoch[4] Validation-Fe2+-accuracy=0.000000
# INFO:root:Epoch[5] Batch [0-1]	Speed: 944.22 samples/sec	cross-entropy=21.497857	Fe2+-accuracy=0.000000
# INFO:root:Epoch[5] Train-cross-entropy=21.497857
# INFO:root:Epoch[5] Train-Fe2+-accuracy=0.000000
# INFO:root:Epoch[5] Time cost=0.039
# INFO:root:Saved checkpoint to "imputer_model/model-0005.params"
# INFO:root:Epoch[5] Validation-cross-entropy=71.912628
# INFO:root:Epoch[5] Validation-Fe2+-accuracy=0.000000
# INFO:root:Epoch[6] Batch [0-1]	Speed: 1106.42 samples/sec	cross-entropy=16.739451	Fe2+-accuracy=0.000000
# INFO:root:Epoch[6] Train-cross-entropy=16.739451
# INFO:root:Epoch[6] Train-Fe2+-accuracy=0.000000
# INFO:root:Epoch[6] Time cost=0.036
# INFO:root:Saved checkpoint to "imputer_model/model-0006.params"
# INFO:root:No improvement detected for 5 epochs compared to 66.57268524169922 last error obtained: 69.29745483398438, stopping here
# INFO:root:
# ========== done (0.4588172435760498 s) fit model

# %%
Fe2_imputed = scale_imputed_data['Fe2+_imputed']

# %% [markdown]
#  ##### Na+ null data imputation

# %%
# Impute null Na+ data using datawig
from datawig import SimpleImputer

# Initialize a simpleImputer model 
imputer = SimpleImputer(input_columns=['Well No', 'T', 'XCO2', 'P', 'Ca2+', 'Fe2+', 'Mg2+', 'pH',
       'HCO3-', 'SO4 2-', 'Cl-', 'CO3 2-', 'TDS', 'Scale Type'], output_column='Na+', output_path = 'imputer_model')

imputer.fit(train_df=scale_data_train)


scale_data_test_imputed = imputer.predict(scale_data_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/datawig/calibration.py:92: RuntimeWarning: invalid value encountered in log
#   return np.log(probas)

# %%
# Predict null Na+ values
imputer.fit(scale_imputed_data)

scale_imputed_data = imputer.predict(scale_data)
# Out:
# WARNING:root:Already bound, ignoring bind()
# /usr/local/lib/python3.7/dist-packages/mxnet/module/base_module.py:503: UserWarning: Parameters already initialized and force_init=False. init_params call ignored.
#   allow_missing=allow_missing, force_init=force_init)
# WARNING:root:optimizer already initialized, ignoring...
# INFO:root:Epoch[0] Batch [0-16]	Speed: 1081.15 samples/sec	cross-entropy=1.335629	Na+-accuracy=0.000000
# INFO:root:Epoch[0] Train-cross-entropy=1.055801
# INFO:root:Epoch[0] Train-Na+-accuracy=0.000000
# INFO:root:Epoch[0] Time cost=0.478
# INFO:root:Saved checkpoint to "imputer_model/model-0000.params"
# INFO:root:Epoch[0] Validation-cross-entropy=0.350384
# INFO:root:Epoch[0] Validation-Na+-accuracy=0.000000
# INFO:root:Epoch[1] Batch [0-16]	Speed: 1126.43 samples/sec	cross-entropy=1.008410	Na+-accuracy=0.000000
# INFO:root:Epoch[1] Train-cross-entropy=0.646763
# INFO:root:Epoch[1] Train-Na+-accuracy=0.000000
# INFO:root:Epoch[1] Time cost=0.448
# INFO:root:Saved checkpoint to "imputer_model/model-0001.params"
# INFO:root:Epoch[1] Validation-cross-entropy=0.431873
# INFO:root:Epoch[1] Validation-Na+-accuracy=0.000000
# INFO:root:Epoch[2] Batch [0-16]	Speed: 1143.13 samples/sec	cross-entropy=0.689102	Na+-accuracy=0.000000
# INFO:root:Epoch[2] Train-cross-entropy=0.522812
# INFO:root:Epoch[2] Train-Na+-accuracy=0.000000
# INFO:root:Epoch[2] Time cost=0.442
# INFO:root:Saved checkpoint to "imputer_model/model-0002.params"
# INFO:root:Epoch[2] Validation-cross-entropy=0.530013
# INFO:root:Epoch[2] Validation-Na+-accuracy=0.000000
# INFO:root:Epoch[3] Batch [0-16]	Speed: 1161.72 samples/sec	cross-entropy=0.456956	Na+-accuracy=0.000000
# INFO:root:Epoch[3] Train-cross-entropy=0.313637
# INFO:root:Epoch[3] Train-Na+-accuracy=0.000000
# INFO:root:Epoch[3] Time cost=0.439
# INFO:root:Saved checkpoint to "imputer_model/model-0003.params"
# INFO:root:Epoch[3] Validation-cross-entropy=0.520614
# INFO:root:Epoch[3] Validation-Na+-accuracy=0.000000
# INFO:root:Epoch[4] Batch [0-16]	Speed: 1134.21 samples/sec	cross-entropy=0.457599	Na+-accuracy=0.000000
# INFO:root:Epoch[4] Train-cross-entropy=0.380979
# INFO:root:Epoch[4] Train-Na+-accuracy=0.000000
# INFO:root:Epoch[4] Time cost=0.443
# INFO:root:Saved checkpoint to "imputer_model/model-0004.params"
# INFO:root:Epoch[4] Validation-cross-entropy=0.535357
# INFO:root:Epoch[4] Validation-Na+-accuracy=0.000000
# INFO:root:Epoch[5] Batch [0-16]	Speed: 1150.51 samples/sec	cross-entropy=0.451156	Na+-accuracy=0.000000
# INFO:root:Epoch[5] Train-cross-entropy=0.324904
# INFO:root:Epoch[5] Train-Na+-accuracy=0.000000
# INFO:root:Epoch[5] Time cost=0.440
# INFO:root:Saved checkpoint to "imputer_model/model-0005.params"
# INFO:root:No improvement detected for 5 epochs compared to 0.35038353875279427 last error obtained: 0.4806494489312172, stopping here
# INFO:root:
# ========== done (3.074519395828247 s) fit model

# %%
Na_imputed = scale_imputed_data['Na+_imputed']

# %% [markdown]
# ##### Mg2+ null data imputation

# %%
# Impute null Mg2+ data using datawig
from datawig import SimpleImputer

# Initialize a simpleImputer model 
imputer = SimpleImputer(input_columns=['Well No', 'T', 'XCO2', 'P', 'Ca2+', 'Fe2+', 'Na+', 'pH',
       'HCO3-', 'SO4 2-', 'Cl-', 'CO3 2-', 'TDS', 'Scale Type'], output_column='Mg2+', output_path = 'imputer_model')

imputer.fit(train_df=scale_data_train)


scale_data_test_imputed = imputer.predict(scale_data_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/datawig/calibration.py:92: RuntimeWarning: invalid value encountered in log
#   return np.log(probas)

# %%
# Predict null Mg2+ values
imputer.fit(scale_imputed_data)

scale_imputed_data = imputer.predict(scale_data)
# Out:
# WARNING:root:Already bound, ignoring bind()
# /usr/local/lib/python3.7/dist-packages/mxnet/module/base_module.py:503: UserWarning: Parameters already initialized and force_init=False. init_params call ignored.
#   allow_missing=allow_missing, force_init=force_init)
# WARNING:root:optimizer already initialized, ignoring...
# INFO:root:Epoch[0] Batch [0-16]	Speed: 1167.42 samples/sec	cross-entropy=1.776713	Mg2+-accuracy=0.000000
# INFO:root:Epoch[0] Train-cross-entropy=2.246136
# INFO:root:Epoch[0] Train-Mg2+-accuracy=0.000000
# INFO:root:Epoch[0] Time cost=0.440
# INFO:root:Saved checkpoint to "imputer_model/model-0000.params"
# INFO:root:Epoch[0] Validation-cross-entropy=3.940439
# INFO:root:Epoch[0] Validation-Mg2+-accuracy=0.000000
# INFO:root:Epoch[1] Batch [0-16]	Speed: 1149.89 samples/sec	cross-entropy=1.670484	Mg2+-accuracy=0.000000
# INFO:root:Epoch[1] Train-cross-entropy=2.061842
# INFO:root:Epoch[1] Train-Mg2+-accuracy=0.000000
# INFO:root:Epoch[1] Time cost=0.452
# INFO:root:Saved checkpoint to "imputer_model/model-0001.params"
# INFO:root:Epoch[1] Validation-cross-entropy=3.538408
# INFO:root:Epoch[1] Validation-Mg2+-accuracy=0.000000
# INFO:root:Epoch[2] Batch [0-16]	Speed: 1164.24 samples/sec	cross-entropy=2.082187	Mg2+-accuracy=0.000000
# INFO:root:Epoch[2] Train-cross-entropy=2.285100
# INFO:root:Epoch[2] Train-Mg2+-accuracy=0.000000
# INFO:root:Epoch[2] Time cost=0.446
# INFO:root:Saved checkpoint to "imputer_model/model-0002.params"
# INFO:root:Epoch[2] Validation-cross-entropy=3.799672
# INFO:root:Epoch[2] Validation-Mg2+-accuracy=0.000000
# INFO:root:Epoch[3] Batch [0-16]	Speed: 1082.47 samples/sec	cross-entropy=1.506073	Mg2+-accuracy=0.000000
# INFO:root:Epoch[3] Train-cross-entropy=1.887186
# INFO:root:Epoch[3] Train-Mg2+-accuracy=0.000000
# INFO:root:Epoch[3] Time cost=0.471
# INFO:root:Saved checkpoint to "imputer_model/model-0003.params"
# INFO:root:Epoch[3] Validation-cross-entropy=3.795866
# INFO:root:Epoch[3] Validation-Mg2+-accuracy=0.000000
# INFO:root:Epoch[4] Batch [0-16]	Speed: 1148.87 samples/sec	cross-entropy=1.520538	Mg2+-accuracy=0.000000
# INFO:root:Epoch[4] Train-cross-entropy=1.852337
# INFO:root:Epoch[4] Train-Mg2+-accuracy=0.000000
# INFO:root:Epoch[4] Time cost=0.437
# INFO:root:Saved checkpoint to "imputer_model/model-0004.params"
# INFO:root:Epoch[4] Validation-cross-entropy=3.927545
# INFO:root:Epoch[4] Validation-Mg2+-accuracy=0.000000
# INFO:root:Epoch[5] Batch [0-16]	Speed: 1119.51 samples/sec	cross-entropy=1.390248	Mg2+-accuracy=0.000000
# INFO:root:Epoch[5] Train-cross-entropy=1.740765
# INFO:root:Epoch[5] Train-Mg2+-accuracy=0.000000
# INFO:root:Epoch[5] Time cost=0.458
# INFO:root:Saved checkpoint to "imputer_model/model-0005.params"
# INFO:root:Epoch[5] Validation-cross-entropy=4.003935
# INFO:root:Epoch[5] Validation-Mg2+-accuracy=0.000000
# INFO:root:Epoch[6] Batch [0-16]	Speed: 1162.69 samples/sec	cross-entropy=1.361420	Mg2+-accuracy=0.000000
# INFO:root:Epoch[6] Train-cross-entropy=1.708281
# INFO:root:Epoch[6] Train-Mg2+-accuracy=0.000000
# INFO:root:Epoch[6] Time cost=0.442
# INFO:root:Saved checkpoint to "imputer_model/model-0006.params"
# INFO:root:No improvement detected for 5 epochs compared to 3.5384079813957214 last error obtained: 4.103609681129456, stopping here
# INFO:root:
# ========== done (3.5908257961273193 s) fit model

# %%
Mg2_imputed = scale_imputed_data['Mg2+_imputed']

# %% [markdown]
# ##### SO4 2- null data imputation

# %%
# Impute null SO4 2- data using datawig
from datawig import SimpleImputer

# Initialize a simpleImputer model 
imputer = SimpleImputer(input_columns=['Well No', 'T', 'XCO2', 'P', 'Ca2+', 'Fe2+', 'Na+', 'pH',
       'HCO3-', 'Mg2+', 'Cl-', 'CO3 2-', 'TDS', 'Scale Type'], output_column='SO4 2-', output_path = 'imputer_model')

imputer.fit(train_df=scale_data_train)


scale_data_test_imputed = imputer.predict(scale_data_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/datawig/calibration.py:92: RuntimeWarning: invalid value encountered in log
#   return np.log(probas)

# %%
# Predict null SO4 2- values
imputer.fit(scale_imputed_data)

scale_imputed_data = imputer.predict(scale_data)
# Out:
# WARNING:root:Already bound, ignoring bind()
# /usr/local/lib/python3.7/dist-packages/mxnet/module/base_module.py:503: UserWarning: Parameters already initialized and force_init=False. init_params call ignored.
#   allow_missing=allow_missing, force_init=force_init)
# WARNING:root:optimizer already initialized, ignoring...
# INFO:root:Epoch[0] Batch [0-16]	Speed: 1176.98 samples/sec	cross-entropy=9.971882	SO4 2--accuracy=0.000000
# INFO:root:Epoch[0] Train-cross-entropy=9.367916
# INFO:root:Epoch[0] Train-SO4 2--accuracy=0.000000
# INFO:root:Epoch[0] Time cost=0.432
# INFO:root:Saved checkpoint to "imputer_model/model-0000.params"
# INFO:root:Epoch[0] Validation-cross-entropy=27.374314
# INFO:root:Epoch[0] Validation-SO4 2--accuracy=0.000000
# INFO:root:Epoch[1] Batch [0-16]	Speed: 1152.46 samples/sec	cross-entropy=10.878751	SO4 2--accuracy=0.000000
# INFO:root:Epoch[1] Train-cross-entropy=10.203362
# INFO:root:Epoch[1] Train-SO4 2--accuracy=0.000000
# INFO:root:Epoch[1] Time cost=0.461
# INFO:root:Saved checkpoint to "imputer_model/model-0001.params"
# INFO:root:Epoch[1] Validation-cross-entropy=28.585226
# INFO:root:Epoch[1] Validation-SO4 2--accuracy=0.000000
# INFO:root:Epoch[2] Batch [0-16]	Speed: 1166.23 samples/sec	cross-entropy=10.081189	SO4 2--accuracy=0.000000
# INFO:root:Epoch[2] Train-cross-entropy=9.341224
# INFO:root:Epoch[2] Train-SO4 2--accuracy=0.000000
# INFO:root:Epoch[2] Time cost=0.432
# INFO:root:Saved checkpoint to "imputer_model/model-0002.params"
# INFO:root:Epoch[2] Validation-cross-entropy=27.840421
# INFO:root:Epoch[2] Validation-SO4 2--accuracy=0.000000
# INFO:root:Epoch[3] Batch [0-16]	Speed: 1172.34 samples/sec	cross-entropy=9.776499	SO4 2--accuracy=0.000000
# INFO:root:Epoch[3] Train-cross-entropy=9.040573
# INFO:root:Epoch[3] Train-SO4 2--accuracy=0.000000
# INFO:root:Epoch[3] Time cost=0.435
# INFO:root:Saved checkpoint to "imputer_model/model-0003.params"
# INFO:root:Epoch[3] Validation-cross-entropy=27.949686
# INFO:root:Epoch[3] Validation-SO4 2--accuracy=0.000000
# INFO:root:Epoch[4] Batch [0-16]	Speed: 1144.73 samples/sec	cross-entropy=9.593724	SO4 2--accuracy=0.000000
# INFO:root:Epoch[4] Train-cross-entropy=8.880710
# INFO:root:Epoch[4] Train-SO4 2--accuracy=0.000000
# INFO:root:Epoch[4] Time cost=0.443
# INFO:root:Saved checkpoint to "imputer_model/model-0004.params"
# INFO:root:Epoch[4] Validation-cross-entropy=28.040058
# INFO:root:Epoch[4] Validation-SO4 2--accuracy=0.000000
# INFO:root:Epoch[5] Batch [0-16]	Speed: 1177.08 samples/sec	cross-entropy=9.581346	SO4 2--accuracy=0.000000
# INFO:root:Epoch[5] Train-cross-entropy=8.815857
# INFO:root:Epoch[5] Train-SO4 2--accuracy=0.000000
# INFO:root:Epoch[5] Time cost=0.445
# INFO:root:Saved checkpoint to "imputer_model/model-0005.params"
# INFO:root:No improvement detected for 5 epochs compared to 27.37431365251541 last error obtained: 27.953789860010147, stopping here
# INFO:root:
# ========== done (3.032923936843872 s) fit model

# %%
SO4_2_imputed = scale_imputed_data['SO4 2-_imputed']

# %% [markdown]
# ##### Cl- null data imputation

# %%
# Impute null Cl- data using datawig
from datawig import SimpleImputer

# Initialize a simpleImputer model 
imputer = SimpleImputer(input_columns=['Well No', 'T', 'XCO2', 'P', 'Ca2+', 'Fe2+', 'Na+', 'pH',
       'HCO3-', 'SO4 2-', 'Mg2+', 'CO3 2-', 'TDS', 'Scale Type'], output_column='Cl-', output_path = 'imputer_model')

imputer.fit(train_df=scale_data_train)


scale_data_test_imputed = imputer.predict(scale_data_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/datawig/calibration.py:92: RuntimeWarning: invalid value encountered in log
#   return np.log(probas)

# %%
# Predict null Cl- values
imputer.fit(scale_imputed_data)

scale_imputed_data = imputer.predict(scale_data)
# Out:
# WARNING:root:Already bound, ignoring bind()
# /usr/local/lib/python3.7/dist-packages/mxnet/module/base_module.py:503: UserWarning: Parameters already initialized and force_init=False. init_params call ignored.
#   allow_missing=allow_missing, force_init=force_init)
# WARNING:root:optimizer already initialized, ignoring...
# INFO:root:Epoch[0] Batch [0-1]	Speed: 1182.20 samples/sec	cross-entropy=61.877474	Cl--accuracy=0.000000
# INFO:root:Epoch[0] Train-cross-entropy=61.877474
# INFO:root:Epoch[0] Train-Cl--accuracy=0.000000
# INFO:root:Epoch[0] Time cost=0.044
# INFO:root:Saved checkpoint to "imputer_model/model-0000.params"
# INFO:root:Epoch[0] Validation-cross-entropy=46.848690
# INFO:root:Epoch[0] Validation-Cl--accuracy=0.000000
# INFO:root:Epoch[1] Batch [0-1]	Speed: 1176.83 samples/sec	cross-entropy=41.873396	Cl--accuracy=0.000000
# INFO:root:Epoch[1] Train-cross-entropy=41.873396
# INFO:root:Epoch[1] Train-Cl--accuracy=0.000000
# INFO:root:Epoch[1] Time cost=0.038
# INFO:root:Saved checkpoint to "imputer_model/model-0001.params"
# INFO:root:Epoch[1] Validation-cross-entropy=43.491516
# INFO:root:Epoch[1] Validation-Cl--accuracy=0.000000
# INFO:root:Epoch[2] Batch [0-1]	Speed: 1176.50 samples/sec	cross-entropy=29.620161	Cl--accuracy=0.000000
# INFO:root:Epoch[2] Train-cross-entropy=29.620161
# INFO:root:Epoch[2] Train-Cl--accuracy=0.000000
# INFO:root:Epoch[2] Time cost=0.036
# INFO:root:Saved checkpoint to "imputer_model/model-0002.params"
# INFO:root:Epoch[2] Validation-cross-entropy=36.289604
# INFO:root:Epoch[2] Validation-Cl--accuracy=0.000000
# INFO:root:Epoch[3] Batch [0-1]	Speed: 1186.51 samples/sec	cross-entropy=24.667113	Cl--accuracy=0.000000
# INFO:root:Epoch[3] Train-cross-entropy=24.667113
# INFO:root:Epoch[3] Train-Cl--accuracy=0.000000
# INFO:root:Epoch[3] Time cost=0.034
# INFO:root:Saved checkpoint to "imputer_model/model-0003.params"
# INFO:root:Epoch[3] Validation-cross-entropy=30.249508
# INFO:root:Epoch[3] Validation-Cl--accuracy=0.000000
# INFO:root:Epoch[4] Batch [0-1]	Speed: 1180.77 samples/sec	cross-entropy=22.767656	Cl--accuracy=0.000000
# INFO:root:Epoch[4] Train-cross-entropy=22.767656
# INFO:root:Epoch[4] Train-Cl--accuracy=0.000000
# INFO:root:Epoch[4] Time cost=0.033
# INFO:root:Saved checkpoint to "imputer_model/model-0004.params"
# INFO:root:Epoch[4] Validation-cross-entropy=25.244322
# INFO:root:Epoch[4] Validation-Cl--accuracy=0.000000
# INFO:root:Epoch[5] Batch [0-1]	Speed: 1189.68 samples/sec	cross-entropy=20.093845	Cl--accuracy=0.000000
# INFO:root:Epoch[5] Train-cross-entropy=20.093845
# INFO:root:Epoch[5] Train-Cl--accuracy=0.000000
# INFO:root:Epoch[5] Time cost=0.033
# INFO:root:Saved checkpoint to "imputer_model/model-0005.params"
# INFO:root:Epoch[5] Validation-cross-entropy=21.318674
# INFO:root:Epoch[5] Validation-Cl--accuracy=0.000000
# INFO:root:Epoch[6] Batch [0-1]	Speed: 1097.73 samples/sec	cross-entropy=15.933339	Cl--accuracy=0.000000
# INFO:root:Epoch[6] Train-cross-entropy=15.933339
# INFO:root:Epoch[6] Train-Cl--accuracy=0.000000
# INFO:root:Epoch[6] Time cost=0.036
# INFO:root:Saved checkpoint to "imputer_model/model-0006.params"
# INFO:root:Epoch[6] Validation-cross-entropy=21.338503
# INFO:root:Epoch[6] Validation-Cl--accuracy=0.000000
# INFO:root:Epoch[7] Batch [0-1]	Speed: 1100.22 samples/sec	cross-entropy=12.965281	Cl--accuracy=0.000000
# INFO:root:Epoch[7] Train-cross-entropy=12.965281
# INFO:root:Epoch[7] Train-Cl--accuracy=0.000000
# INFO:root:Epoch[7] Time cost=0.036
# INFO:root:Saved checkpoint to "imputer_model/model-0007.params"
# INFO:root:Epoch[7] Validation-cross-entropy=22.507906
# INFO:root:Epoch[7] Validation-Cl--accuracy=0.000000
# INFO:root:Epoch[8] Batch [0-1]	Speed: 1091.95 samples/sec	cross-entropy=11.007815	Cl--accuracy=0.000000
# INFO:root:Epoch[8] Train-cross-entropy=11.007815
# INFO:root:Epoch[8] Train-Cl--accuracy=0.000000
# INFO:root:Epoch[8] Time cost=0.038
# INFO:root:Saved checkpoint to "imputer_model/model-0008.params"
# INFO:root:Epoch[8] Validation-cross-entropy=20.453449
# INFO:root:Epoch[8] Validation-Cl--accuracy=0.000000
# INFO:root:Epoch[9] Batch [0-1]	Speed: 1140.86 samples/sec	cross-entropy=9.298134	Cl--accuracy=0.000000
# INFO:root:Epoch[9] Train-cross-entropy=9.298134
# INFO:root:Epoch[9] Train-Cl--accuracy=0.000000
# INFO:root:Epoch[9] Time cost=0.036
# INFO:root:Saved checkpoint to "imputer_model/model-0009.params"
# INFO:root:Epoch[9] Validation-cross-entropy=17.129023
# INFO:root:Epoch[9] Validation-Cl--accuracy=0.000000
# INFO:root:Epoch[10] Batch [0-1]	Speed: 1120.27 samples/sec	cross-entropy=8.551976	Cl--accuracy=0.000000
# INFO:root:Epoch[10] Train-cross-entropy=8.551976
# INFO:root:Epoch[10] Train-Cl--accuracy=0.000000
# INFO:root:Epoch[10] Time cost=0.038
# INFO:root:Saved checkpoint to "imputer_model/model-0010.params"
# INFO:root:Epoch[10] Validation-cross-entropy=15.378661
# INFO:root:Epoch[10] Validation-Cl--accuracy=0.000000
# INFO:root:Epoch[11] Batch [0-1]	Speed: 1129.55 samples/sec	cross-entropy=8.101171	Cl--accuracy=0.000000
# INFO:root:Epoch[11] Train-cross-entropy=8.101171
# INFO:root:Epoch[11] Train-Cl--accuracy=0.000000
# INFO:root:Epoch[11] Time cost=0.037
# INFO:root:Saved checkpoint to "imputer_model/model-0011.params"
# INFO:root:Epoch[11] Validation-cross-entropy=15.200084
# INFO:root:Epoch[11] Validation-Cl--accuracy=0.000000
# INFO:root:Epoch[12] Batch [0-1]	Speed: 1121.75 samples/sec	cross-entropy=7.323940	Cl--accuracy=0.000000
# INFO:root:Epoch[12] Train-cross-entropy=7.323940
# INFO:root:Epoch[12] Train-Cl--accuracy=0.000000
# INFO:root:Epoch[12] Time cost=0.034
# INFO:root:Saved checkpoint to "imputer_model/model-0012.params"
# INFO:root:Epoch[12] Validation-cross-entropy=15.785503
# INFO:root:Epoch[12] Validation-Cl--accuracy=0.000000
# INFO:root:Epoch[13] Batch [0-1]	Speed: 990.27 samples/sec	cross-entropy=6.678370	Cl--accuracy=0.000000
# INFO:root:Epoch[13] Train-cross-entropy=6.678370
# INFO:root:Epoch[13] Train-Cl--accuracy=0.000000
# INFO:root:Epoch[13] Time cost=0.038
# INFO:root:Saved checkpoint to "imputer_model/model-0013.params"
# INFO:root:Epoch[13] Validation-cross-entropy=16.217052
# INFO:root:Epoch[13] Validation-Cl--accuracy=0.000000
# INFO:root:Epoch[14] Batch [0-1]	Speed: 1162.16 samples/sec	cross-entropy=6.037920	Cl--accuracy=0.000000
# INFO:root:Epoch[14] Train-cross-entropy=6.037920
# INFO:root:Epoch[14] Train-Cl--accuracy=0.000000
# INFO:root:Epoch[14] Time cost=0.034
# INFO:root:Saved checkpoint to "imputer_model/model-0014.params"
# INFO:root:Epoch[14] Validation-cross-entropy=16.063799
# INFO:root:Epoch[14] Validation-Cl--accuracy=0.000000
# INFO:root:Epoch[15] Batch [0-1]	Speed: 958.92 samples/sec	cross-entropy=5.499850	Cl--accuracy=0.000000
# INFO:root:Epoch[15] Train-cross-entropy=5.499850
# INFO:root:Epoch[15] Train-Cl--accuracy=0.000000
# INFO:root:Epoch[15] Time cost=0.037
# INFO:root:Saved checkpoint to "imputer_model/model-0015.params"
# INFO:root:No improvement detected for 5 epochs compared to 15.378661155700684 last error obtained: 15.877501487731934, stopping here
# INFO:root:
# ========== done (0.9979255199432373 s) fit model
# /usr/local/lib/python3.7/dist-packages/datawig/calibration.py:92: RuntimeWarning: invalid value encountered in log
#   return np.log(probas)

# %%
Cl_imputed = scale_imputed_data['Cl-_imputed']

# %% [markdown]
# ##### CO3 2- null data imputation

# %%
# Impute null CO3 2- data using datawig
from datawig import SimpleImputer

# Initialize a simpleImputer model 
imputer = SimpleImputer(input_columns=['Well No', 'T', 'XCO2', 'P', 'Ca2+', 'Fe2+', 'Na+', 'pH',
       'HCO3-', 'SO4 2-', 'Cl-', 'Mg2+', 'TDS', 'Scale Type'], output_column='CO3 2-', output_path = 'imputer_model')

imputer.fit(train_df=scale_data_train)


scale_data_test_imputed = imputer.predict(scale_data_test)

# %%
# Predict null CO3 2- values
imputer.fit(scale_imputed_data)

scale_imputed_data = imputer.predict(scale_data)
# Out:
# WARNING:root:Already bound, ignoring bind()
# /usr/local/lib/python3.7/dist-packages/mxnet/module/base_module.py:503: UserWarning: Parameters already initialized and force_init=False. init_params call ignored.
#   allow_missing=allow_missing, force_init=force_init)
# WARNING:root:optimizer already initialized, ignoring...
# INFO:root:Epoch[0] Batch [0-1]	Speed: 1106.02 samples/sec	cross-entropy=246.051598	CO3 2--accuracy=0.000000
# INFO:root:Epoch[0] Train-cross-entropy=246.051598
# INFO:root:Epoch[0] Train-CO3 2--accuracy=0.000000
# INFO:root:Epoch[0] Time cost=0.036
# INFO:root:Saved checkpoint to "imputer_model/model-0000.params"
# INFO:root:Epoch[0] Validation-cross-entropy=87.254333
# INFO:root:Epoch[0] Validation-CO3 2--accuracy=0.000000
# INFO:root:Epoch[1] Batch [0-1]	Speed: 1015.23 samples/sec	cross-entropy=224.207458	CO3 2--accuracy=0.000000
# INFO:root:Epoch[1] Train-cross-entropy=224.207458
# INFO:root:Epoch[1] Train-CO3 2--accuracy=0.000000
# INFO:root:Epoch[1] Time cost=0.038
# INFO:root:Saved checkpoint to "imputer_model/model-0001.params"
# INFO:root:Epoch[1] Validation-cross-entropy=55.345909
# INFO:root:Epoch[1] Validation-CO3 2--accuracy=0.000000
# INFO:root:Epoch[2] Batch [0-1]	Speed: 1060.57 samples/sec	cross-entropy=209.590599	CO3 2--accuracy=0.000000
# INFO:root:Epoch[2] Train-cross-entropy=209.590599
# INFO:root:Epoch[2] Train-CO3 2--accuracy=0.000000
# INFO:root:Epoch[2] Time cost=0.035
# INFO:root:Saved checkpoint to "imputer_model/model-0002.params"
# INFO:root:Epoch[2] Validation-cross-entropy=33.692738
# INFO:root:Epoch[2] Validation-CO3 2--accuracy=0.000000
# INFO:root:Epoch[3] Batch [0-1]	Speed: 1158.99 samples/sec	cross-entropy=198.531170	CO3 2--accuracy=0.000000
# INFO:root:Epoch[3] Train-cross-entropy=198.531170
# INFO:root:Epoch[3] Train-CO3 2--accuracy=0.000000
# INFO:root:Epoch[3] Time cost=0.041
# INFO:root:Saved checkpoint to "imputer_model/model-0003.params"
# INFO:root:Epoch[3] Validation-cross-entropy=22.030790
# INFO:root:Epoch[3] Validation-CO3 2--accuracy=0.000000
# INFO:root:Epoch[4] Batch [0-1]	Speed: 1007.96 samples/sec	cross-entropy=188.933453	CO3 2--accuracy=0.000000
# INFO:root:Epoch[4] Train-cross-entropy=188.933453
# INFO:root:Epoch[4] Train-CO3 2--accuracy=0.000000
# INFO:root:Epoch[4] Time cost=0.041
# INFO:root:Saved checkpoint to "imputer_model/model-0004.params"
# INFO:root:Epoch[4] Validation-cross-entropy=18.080000
# INFO:root:Epoch[4] Validation-CO3 2--accuracy=0.000000
# INFO:root:Epoch[5] Batch [0-1]	Speed: 1087.31 samples/sec	cross-entropy=182.534590	CO3 2--accuracy=0.000000
# INFO:root:Epoch[5] Train-cross-entropy=182.534590
# INFO:root:Epoch[5] Train-CO3 2--accuracy=0.000000
# INFO:root:Epoch[5] Time cost=0.036
# INFO:root:Saved checkpoint to "imputer_model/model-0005.params"
# INFO:root:Epoch[5] Validation-cross-entropy=20.727509
# INFO:root:Epoch[5] Validation-CO3 2--accuracy=0.000000
# INFO:root:Epoch[6] Batch [0-1]	Speed: 1016.05 samples/sec	cross-entropy=177.928616	CO3 2--accuracy=0.000000
# INFO:root:Epoch[6] Train-cross-entropy=177.928616
# INFO:root:Epoch[6] Train-CO3 2--accuracy=0.000000
# INFO:root:Epoch[6] Time cost=0.040
# INFO:root:Saved checkpoint to "imputer_model/model-0006.params"
# INFO:root:Epoch[6] Validation-cross-entropy=28.156300
# INFO:root:Epoch[6] Validation-CO3 2--accuracy=0.000000
# INFO:root:Epoch[7] Batch [0-1]	Speed: 1043.20 samples/sec	cross-entropy=173.492664	CO3 2--accuracy=0.000000
# INFO:root:Epoch[7] Train-cross-entropy=173.492664
# INFO:root:Epoch[7] Train-CO3 2--accuracy=0.000000
# INFO:root:Epoch[7] Time cost=0.038
# INFO:root:Saved checkpoint to "imputer_model/model-0007.params"
# INFO:root:Epoch[7] Validation-cross-entropy=36.139065
# INFO:root:Epoch[7] Validation-CO3 2--accuracy=0.000000
# INFO:root:Epoch[8] Batch [0-1]	Speed: 1132.22 samples/sec	cross-entropy=169.221479	CO3 2--accuracy=0.000000
# INFO:root:Epoch[8] Train-cross-entropy=169.221479
# INFO:root:Epoch[8] Train-CO3 2--accuracy=0.000000
# INFO:root:Epoch[8] Time cost=0.038
# INFO:root:Saved checkpoint to "imputer_model/model-0008.params"
# INFO:root:Epoch[8] Validation-cross-entropy=40.359783
# INFO:root:Epoch[8] Validation-CO3 2--accuracy=0.000000
# INFO:root:Epoch[9] Batch [0-1]	Speed: 1015.54 samples/sec	cross-entropy=164.507341	CO3 2--accuracy=0.000000
# INFO:root:Epoch[9] Train-cross-entropy=164.507341
# INFO:root:Epoch[9] Train-CO3 2--accuracy=0.000000
# INFO:root:Epoch[9] Time cost=0.041
# INFO:root:Saved checkpoint to "imputer_model/model-0009.params"
# INFO:root:No improvement detected for 5 epochs compared to 18.079999923706055 last error obtained: 39.34556198120117, stopping here
# INFO:root:
# ========== done (0.652019739151001 s) fit model

# %%
CO3_2_imputed = scale_imputed_data['CO3 2-_imputed']

# %% [markdown]
# ##### TDS null data imputation

# %%
# Impute null TDS data using datawig
from datawig import SimpleImputer

# Initialize a simpleImputer model 
imputer = SimpleImputer(input_columns=['Well No', 'T', 'XCO2', 'P', 'Ca2+', 'Fe2+', 'Na+', 'pH',
       'HCO3-', 'SO4 2-', 'Cl-', 'CO3 2-', 'Mg2+', 'Scale Type'], output_column='TDS', output_path = 'imputer_model')

imputer.fit(train_df=scale_data_train)


scale_data_test_imputed = imputer.predict(scale_data_test)

# %%
# Predict null TDS values
imputer.fit(scale_imputed_data)

scale_imputed_data = imputer.predict(scale_data)
# Out:
# WARNING:root:Already bound, ignoring bind()
# /usr/local/lib/python3.7/dist-packages/mxnet/module/base_module.py:503: UserWarning: Parameters already initialized and force_init=False. init_params call ignored.
#   allow_missing=allow_missing, force_init=force_init)
# WARNING:root:optimizer already initialized, ignoring...
# INFO:root:Epoch[0] Batch [0-15]	Speed: 1078.40 samples/sec	cross-entropy=0.320204	TDS-accuracy=0.000000
# INFO:root:Epoch[0] Train-cross-entropy=0.302156
# INFO:root:Epoch[0] Train-TDS-accuracy=0.000000
# INFO:root:Epoch[0] Time cost=0.456
# INFO:root:Saved checkpoint to "imputer_model/model-0000.params"
# INFO:root:Epoch[0] Validation-cross-entropy=0.182021
# INFO:root:Epoch[0] Validation-TDS-accuracy=0.000000
# INFO:root:Epoch[1] Batch [0-15]	Speed: 1067.45 samples/sec	cross-entropy=1.410118	TDS-accuracy=0.000000
# INFO:root:Epoch[1] Train-cross-entropy=1.149034
# INFO:root:Epoch[1] Train-TDS-accuracy=0.000000
# INFO:root:Epoch[1] Time cost=0.449
# INFO:root:Saved checkpoint to "imputer_model/model-0001.params"
# INFO:root:Epoch[1] Validation-cross-entropy=0.306944
# INFO:root:Epoch[1] Validation-TDS-accuracy=0.000000
# INFO:root:Epoch[2] Batch [0-15]	Speed: 1056.14 samples/sec	cross-entropy=0.334445	TDS-accuracy=0.000000
# INFO:root:Epoch[2] Train-cross-entropy=0.234999
# INFO:root:Epoch[2] Train-TDS-accuracy=0.000000
# INFO:root:Epoch[2] Time cost=0.458
# INFO:root:Saved checkpoint to "imputer_model/model-0002.params"
# INFO:root:Epoch[2] Validation-cross-entropy=0.127941
# INFO:root:Epoch[2] Validation-TDS-accuracy=0.000000
# INFO:root:Epoch[3] Batch [0-15]	Speed: 1069.49 samples/sec	cross-entropy=0.392541	TDS-accuracy=0.000000
# INFO:root:Epoch[3] Train-cross-entropy=0.305469
# INFO:root:Epoch[3] Train-TDS-accuracy=0.000000
# INFO:root:Epoch[3] Time cost=0.454
# INFO:root:Saved checkpoint to "imputer_model/model-0003.params"
# INFO:root:Epoch[3] Validation-cross-entropy=0.139468
# INFO:root:Epoch[3] Validation-TDS-accuracy=0.000000
# INFO:root:Epoch[4] Batch [0-15]	Speed: 1062.47 samples/sec	cross-entropy=0.168231	TDS-accuracy=0.000000
# INFO:root:Epoch[4] Train-cross-entropy=0.138808
# INFO:root:Epoch[4] Train-TDS-accuracy=0.000000
# INFO:root:Epoch[4] Time cost=0.465
# INFO:root:Saved checkpoint to "imputer_model/model-0004.params"
# INFO:root:Epoch[4] Validation-cross-entropy=0.099347
# INFO:root:Epoch[4] Validation-TDS-accuracy=0.000000
# INFO:root:Epoch[5] Batch [0-15]	Speed: 1064.64 samples/sec	cross-entropy=0.198133	TDS-accuracy=0.000000
# INFO:root:Epoch[5] Train-cross-entropy=0.160168
# INFO:root:Epoch[5] Train-TDS-accuracy=0.000000
# INFO:root:Epoch[5] Time cost=0.446
# INFO:root:Saved checkpoint to "imputer_model/model-0005.params"
# INFO:root:Epoch[5] Validation-cross-entropy=0.092281
# INFO:root:Epoch[5] Validation-TDS-accuracy=0.000000
# INFO:root:Epoch[6] Batch [0-15]	Speed: 1077.07 samples/sec	cross-entropy=0.143331	TDS-accuracy=0.000000
# INFO:root:Epoch[6] Train-cross-entropy=0.115443
# INFO:root:Epoch[6] Train-TDS-accuracy=0.000000
# INFO:root:Epoch[6] Time cost=0.455
# INFO:root:Saved checkpoint to "imputer_model/model-0006.params"
# INFO:root:Epoch[6] Validation-cross-entropy=0.080231
# INFO:root:Epoch[6] Validation-TDS-accuracy=0.000000
# INFO:root:Epoch[7] Batch [0-15]	Speed: 1072.59 samples/sec	cross-entropy=0.145899	TDS-accuracy=0.000000
# INFO:root:Epoch[7] Train-cross-entropy=0.115516
# INFO:root:Epoch[7] Train-TDS-accuracy=0.000000
# INFO:root:Epoch[7] Time cost=0.441
# INFO:root:Saved checkpoint to "imputer_model/model-0007.params"
# INFO:root:Epoch[7] Validation-cross-entropy=0.068058
# INFO:root:Epoch[7] Validation-TDS-accuracy=0.000000
# INFO:root:Epoch[8] Batch [0-15]	Speed: 1052.92 samples/sec	cross-entropy=0.120319	TDS-accuracy=0.000000
# INFO:root:Epoch[8] Train-cross-entropy=0.095209
# INFO:root:Epoch[8] Train-TDS-accuracy=0.000000
# INFO:root:Epoch[8] Time cost=0.448
# INFO:root:Saved checkpoint to "imputer_model/model-0008.params"
# INFO:root:Epoch[8] Validation-cross-entropy=0.062368
# INFO:root:Epoch[8] Validation-TDS-accuracy=0.000000
# INFO:root:Epoch[9] Batch [0-15]	Speed: 1068.69 samples/sec	cross-entropy=0.115092	TDS-accuracy=0.000000
# INFO:root:Epoch[9] Train-cross-entropy=0.087079
# INFO:root:Epoch[9] Train-TDS-accuracy=0.000000
# INFO:root:Epoch[9] Time cost=0.448
# INFO:root:Saved checkpoint to "imputer_model/model-0009.params"
# INFO:root:Epoch[9] Validation-cross-entropy=0.053867
# INFO:root:Epoch[9] Validation-TDS-accuracy=0.000000
# INFO:root:Epoch[10] Batch [0-15]	Speed: 1040.07 samples/sec	cross-entropy=0.102492	TDS-accuracy=0.000000
# INFO:root:Epoch[10] Train-cross-entropy=0.077336
# INFO:root:Epoch[10] Train-TDS-accuracy=0.000000
# INFO:root:Epoch[10] Time cost=0.449
# INFO:root:Saved checkpoint to "imputer_model/model-0010.params"
# INFO:root:Epoch[10] Validation-cross-entropy=0.050421
# INFO:root:Epoch[10] Validation-TDS-accuracy=0.000000
# INFO:root:Epoch[11] Batch [0-15]	Speed: 1025.09 samples/sec	cross-entropy=0.092726	TDS-accuracy=0.000000
# INFO:root:Epoch[11] Train-cross-entropy=0.068142
# INFO:root:Epoch[11] Train-TDS-accuracy=0.000000
# INFO:root:Epoch[11] Time cost=0.449
# INFO:root:Saved checkpoint to "imputer_model/model-0011.params"
# INFO:root:Epoch[11] Validation-cross-entropy=0.044180
# INFO:root:Epoch[11] Validation-TDS-accuracy=0.000000
# INFO:root:Epoch[12] Batch [0-15]	Speed: 1109.45 samples/sec	cross-entropy=0.085121	TDS-accuracy=0.000000
# INFO:root:Epoch[12] Train-cross-entropy=0.061341
# INFO:root:Epoch[12] Train-TDS-accuracy=0.000000
# INFO:root:Epoch[12] Time cost=0.419
# INFO:root:Saved checkpoint to "imputer_model/model-0012.params"
# INFO:root:Epoch[12] Validation-cross-entropy=0.043903
# INFO:root:Epoch[12] Validation-TDS-accuracy=0.000000
# INFO:root:Epoch[13] Batch [0-15]	Speed: 1145.42 samples/sec	cross-entropy=0.077461	TDS-accuracy=0.000000
# INFO:root:Epoch[13] Train-cross-entropy=0.055382
# INFO:root:Epoch[13] Train-TDS-accuracy=0.000000
# INFO:root:Epoch[13] Time cost=0.411
# INFO:root:Saved checkpoint to "imputer_model/model-0013.params"
# INFO:root:Epoch[13] Validation-cross-entropy=0.040029
# INFO:root:Epoch[13] Validation-TDS-accuracy=0.000000
# INFO:root:Epoch[14] Batch [0-15]	Speed: 1157.80 samples/sec	cross-entropy=0.070991	TDS-accuracy=0.000000
# INFO:root:Epoch[14] Train-cross-entropy=0.048508
# INFO:root:Epoch[14] Train-TDS-accuracy=0.000000
# INFO:root:Epoch[14] Time cost=0.413
# INFO:root:Saved checkpoint to "imputer_model/model-0014.params"
# INFO:root:Epoch[14] Validation-cross-entropy=0.038450
# INFO:root:Epoch[14] Validation-TDS-accuracy=0.000000
# INFO:root:Epoch[15] Batch [0-15]	Speed: 1136.45 samples/sec	cross-entropy=0.066449	TDS-accuracy=0.000000
# INFO:root:Epoch[15] Train-cross-entropy=0.044963
# INFO:root:Epoch[15] Train-TDS-accuracy=0.000000
# INFO:root:Epoch[15] Time cost=0.415
# INFO:root:Saved checkpoint to "imputer_model/model-0015.params"
# INFO:root:Epoch[15] Validation-cross-entropy=0.038863
# INFO:root:Epoch[15] Validation-TDS-accuracy=0.000000
# INFO:root:Epoch[16] Batch [0-15]	Speed: 1141.83 samples/sec	cross-entropy=0.062085	TDS-accuracy=0.000000
# INFO:root:Epoch[16] Train-cross-entropy=0.041174
# INFO:root:Epoch[16] Train-TDS-accuracy=0.000000
# INFO:root:Epoch[16] Time cost=0.418
# INFO:root:Saved checkpoint to "imputer_model/model-0016.params"
# INFO:root:Epoch[16] Validation-cross-entropy=0.036967
# INFO:root:Epoch[16] Validation-TDS-accuracy=0.000000
# INFO:root:Epoch[17] Batch [0-15]	Speed: 1126.85 samples/sec	cross-entropy=0.058606	TDS-accuracy=0.000000
# INFO:root:Epoch[17] Train-cross-entropy=0.038707
# INFO:root:Epoch[17] Train-TDS-accuracy=0.000000
# INFO:root:Epoch[17] Time cost=0.425
# INFO:root:Saved checkpoint to "imputer_model/model-0017.params"
# INFO:root:Epoch[17] Validation-cross-entropy=0.036585
# INFO:root:Epoch[17] Validation-TDS-accuracy=0.000000
# INFO:root:Epoch[18] Batch [0-15]	Speed: 1149.97 samples/sec	cross-entropy=0.055830	TDS-accuracy=0.000000
# INFO:root:Epoch[18] Train-cross-entropy=0.036605
# INFO:root:Epoch[18] Train-TDS-accuracy=0.000000
# INFO:root:Epoch[18] Time cost=0.415
# INFO:root:Saved checkpoint to "imputer_model/model-0018.params"
# INFO:root:Epoch[18] Validation-cross-entropy=0.034916
# INFO:root:Epoch[18] Validation-TDS-accuracy=0.000000
# INFO:root:Epoch[19] Batch [0-15]	Speed: 1150.32 samples/sec	cross-entropy=0.053512	TDS-accuracy=0.000000
# INFO:root:Epoch[19] Train-cross-entropy=0.034706
# INFO:root:Epoch[19] Train-TDS-accuracy=0.000000
# INFO:root:Epoch[19] Time cost=0.416
# INFO:root:Saved checkpoint to "imputer_model/model-0019.params"
# INFO:root:Epoch[19] Validation-cross-entropy=0.034936
# INFO:root:Epoch[19] Validation-TDS-accuracy=0.000000
# INFO:root:Epoch[20] Batch [0-15]	Speed: 1140.78 samples/sec	cross-entropy=0.051744	TDS-accuracy=0.000000
# INFO:root:Epoch[20] Train-cross-entropy=0.033601
# INFO:root:Epoch[20] Train-TDS-accuracy=0.000000
# INFO:root:Epoch[20] Time cost=0.417
# INFO:root:Saved checkpoint to "imputer_model/model-0020.params"
# INFO:root:Epoch[20] Validation-cross-entropy=0.033024
# INFO:root:Epoch[20] Validation-TDS-accuracy=0.000000
# INFO:root:Epoch[21] Batch [0-15]	Speed: 1168.08 samples/sec	cross-entropy=0.050377	TDS-accuracy=0.000000
# INFO:root:Epoch[21] Train-cross-entropy=0.032329
# INFO:root:Epoch[21] Train-TDS-accuracy=0.000000
# INFO:root:Epoch[21] Time cost=0.411
# INFO:root:Saved checkpoint to "imputer_model/model-0021.params"
# INFO:root:Epoch[21] Validation-cross-entropy=0.033274
# INFO:root:Epoch[21] Validation-TDS-accuracy=0.000000
# INFO:root:Epoch[22] Batch [0-15]	Speed: 1178.56 samples/sec	cross-entropy=0.049299	TDS-accuracy=0.000000
# INFO:root:Epoch[22] Train-cross-entropy=0.031788
# INFO:root:Epoch[22] Train-TDS-accuracy=0.000000
# INFO:root:Epoch[22] Time cost=0.416
# INFO:root:Saved checkpoint to "imputer_model/model-0022.params"
# INFO:root:Epoch[22] Validation-cross-entropy=0.032390
# INFO:root:Epoch[22] Validation-TDS-accuracy=0.000000
# INFO:root:Epoch[23] Batch [0-15]	Speed: 1171.47 samples/sec	cross-entropy=0.048546	TDS-accuracy=0.000000
# INFO:root:Epoch[23] Train-cross-entropy=0.031021
# INFO:root:Epoch[23] Train-TDS-accuracy=0.000000
# INFO:root:Epoch[23] Time cost=0.408
# INFO:root:Saved checkpoint to "imputer_model/model-0023.params"
# INFO:root:Epoch[23] Validation-cross-entropy=0.030246
# INFO:root:Epoch[23] Validation-TDS-accuracy=0.000000
# INFO:root:Epoch[24] Batch [0-15]	Speed: 1128.14 samples/sec	cross-entropy=0.047700	TDS-accuracy=0.000000
# INFO:root:Epoch[24] Train-cross-entropy=0.030823
# INFO:root:Epoch[24] Train-TDS-accuracy=0.000000
# INFO:root:Epoch[24] Time cost=0.417
# INFO:root:Saved checkpoint to "imputer_model/model-0024.params"
# INFO:root:Epoch[24] Validation-cross-entropy=0.031668
# INFO:root:Epoch[24] Validation-TDS-accuracy=0.000000
# INFO:root:Epoch[25] Batch [0-15]	Speed: 1136.65 samples/sec	cross-entropy=0.047420	TDS-accuracy=0.000000
# INFO:root:Epoch[25] Train-cross-entropy=0.030444
# INFO:root:Epoch[25] Train-TDS-accuracy=0.000000
# INFO:root:Epoch[25] Time cost=0.412
# INFO:root:Saved checkpoint to "imputer_model/model-0025.params"
# INFO:root:Epoch[25] Validation-cross-entropy=0.028474
# INFO:root:Epoch[25] Validation-TDS-accuracy=0.000000
# INFO:root:Epoch[26] Batch [0-15]	Speed: 1157.12 samples/sec	cross-entropy=0.046893	TDS-accuracy=0.000000
# INFO:root:Epoch[26] Train-cross-entropy=0.030459
# INFO:root:Epoch[26] Train-TDS-accuracy=0.000000
# INFO:root:Epoch[26] Time cost=0.414
# INFO:root:Saved checkpoint to "imputer_model/model-0026.params"
# INFO:root:Epoch[26] Validation-cross-entropy=0.029362
# INFO:root:Epoch[26] Validation-TDS-accuracy=0.000000
# INFO:root:Epoch[27] Batch [0-15]	Speed: 1029.98 samples/sec	cross-entropy=0.046835	TDS-accuracy=0.000000
# INFO:root:Epoch[27] Train-cross-entropy=0.030460
# INFO:root:Epoch[27] Train-TDS-accuracy=0.000000
# INFO:root:Epoch[27] Time cost=0.443
# INFO:root:Saved checkpoint to "imputer_model/model-0027.params"
# INFO:root:Epoch[27] Validation-cross-entropy=0.028175
# INFO:root:Epoch[27] Validation-TDS-accuracy=0.000000
# INFO:root:Epoch[28] Batch [0-15]	Speed: 1107.96 samples/sec	cross-entropy=0.046650	TDS-accuracy=0.000000
# INFO:root:Epoch[28] Train-cross-entropy=0.030146
# INFO:root:Epoch[28] Train-TDS-accuracy=0.000000
# INFO:root:Epoch[28] Time cost=0.424
# INFO:root:Saved checkpoint to "imputer_model/model-0028.params"
# INFO:root:Epoch[28] Validation-cross-entropy=0.028541
# INFO:root:Epoch[28] Validation-TDS-accuracy=0.000000
# INFO:root:Epoch[29] Batch [0-15]	Speed: 1144.81 samples/sec	cross-entropy=0.046092	TDS-accuracy=0.000000
# INFO:root:Epoch[29] Train-cross-entropy=0.030011
# INFO:root:Epoch[29] Train-TDS-accuracy=0.000000
# INFO:root:Epoch[29] Time cost=0.411
# INFO:root:Saved checkpoint to "imputer_model/model-0029.params"
# INFO:root:Epoch[29] Validation-cross-entropy=0.029763
# INFO:root:Epoch[29] Validation-TDS-accuracy=0.000000
# INFO:root:Epoch[30] Batch [0-15]	Speed: 1164.27 samples/sec	cross-entropy=0.046106	TDS-accuracy=0.000000
# INFO:root:Epoch[30] Train-cross-entropy=0.029871
# INFO:root:Epoch[30] Train-TDS-accuracy=0.000000
# INFO:root:Epoch[30] Time cost=0.415
# INFO:root:Saved checkpoint to "imputer_model/model-0030.params"
# INFO:root:Epoch[30] Validation-cross-entropy=0.029859
# INFO:root:Epoch[30] Validation-TDS-accuracy=0.000000
# INFO:root:Epoch[31] Batch [0-15]	Speed: 1152.19 samples/sec	cross-entropy=0.045723	TDS-accuracy=0.000000
# INFO:root:Epoch[31] Train-cross-entropy=0.029911
# INFO:root:Epoch[31] Train-TDS-accuracy=0.000000
# INFO:root:Epoch[31] Time cost=0.411
# INFO:root:Saved checkpoint to "imputer_model/model-0031.params"
# INFO:root:Epoch[31] Validation-cross-entropy=0.029836
# INFO:root:Epoch[31] Validation-TDS-accuracy=0.000000
# INFO:root:Epoch[32] Batch [0-15]	Speed: 1168.50 samples/sec	cross-entropy=0.045445	TDS-accuracy=0.000000
# INFO:root:Epoch[32] Train-cross-entropy=0.029920
# INFO:root:Epoch[32] Train-TDS-accuracy=0.000000
# INFO:root:Epoch[32] Time cost=0.406
# INFO:root:Saved checkpoint to "imputer_model/model-0032.params"
# INFO:root:No improvement detected for 5 epochs compared to 0.02817455178592354 last error obtained: 0.029437334480462596, stopping here
# INFO:root:
# ========== done (16.312691926956177 s) fit model

# %%
TDS_imputed = scale_imputed_data['TDS_imputed']

# %% [markdown]
# ##### Scale Type null data imputation

# %%
# Impute null Scale Type data using datawig
from datawig import SimpleImputer

# Initialize a simpleImputer model 
imputer = SimpleImputer(input_columns=['Well No', 'T', 'XCO2', 'P', 'Ca2+', 'Fe2+', 'Na+', 'pH',
       'HCO3-', 'SO4 2-', 'Cl-', 'CO3 2-', 'TDS', 'Mg2+'], output_column='Scale Type', output_path = 'imputer_model')

imputer.fit(train_df=scale_data_train)


scale_data_test_imputed = imputer.predict(scale_data_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:4213: FutureWarning: 'is_extension_type' is deprecated and will be removed in a future version.  Use 'is_extension_array_dtype' instead.
#   if callable(index) or is_dict_like(index):
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:4213: FutureWarning: 'is_extension_type' is deprecated and will be removed in a future version.  Use 'is_extension_array_dtype' instead.
#   if callable(index) or is_dict_like(index):
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:4213: FutureWarning: 'is_extension_type' is deprecated and will be removed in a future version.  Use 'is_extension_array_dtype' instead.
#   if callable(index) or is_dict_like(index):

# %%
# Predict null Scale Type values
imputer.fit(scale_imputed_data)

scale_imputed_data = imputer.predict(scale_data)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:4213: FutureWarning: 'is_extension_type' is deprecated and will be removed in a future version.  Use 'is_extension_array_dtype' instead.
#   if callable(index) or is_dict_like(index):
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:4213: FutureWarning: 'is_extension_type' is deprecated and will be removed in a future version.  Use 'is_extension_array_dtype' instead.
#   if callable(index) or is_dict_like(index):
# WARNING:root:Already bound, ignoring bind()
# /usr/local/lib/python3.7/dist-packages/mxnet/module/base_module.py:503: UserWarning: Parameters already initialized and force_init=False. init_params call ignored.
#   allow_missing=allow_missing, force_init=force_init)
# WARNING:root:optimizer already initialized, ignoring...
# INFO:root:Epoch[0] Batch [0-16]	Speed: 12576.62 samples/sec	cross-entropy=0.013498	Scale Type-accuracy=0.996324
# INFO:root:Epoch[0] Train-cross-entropy=0.008373
# INFO:root:Epoch[0] Train-Scale Type-accuracy=0.997984
# INFO:root:Epoch[0] Time cost=0.045
# INFO:root:Saved checkpoint to "imputer_model/model-0000.params"
# INFO:root:Epoch[0] Validation-cross-entropy=0.008278
# INFO:root:Epoch[0] Validation-Scale Type-accuracy=1.000000
# INFO:root:Epoch[1] Batch [0-16]	Speed: 13635.16 samples/sec	cross-entropy=0.001787	Scale Type-accuracy=1.000000
# INFO:root:Epoch[1] Train-cross-entropy=0.001417
# INFO:root:Epoch[1] Train-Scale Type-accuracy=1.000000
# INFO:root:Epoch[1] Time cost=0.043
# INFO:root:Saved checkpoint to "imputer_model/model-0001.params"
# INFO:root:Epoch[1] Validation-cross-entropy=0.006920
# INFO:root:Epoch[1] Validation-Scale Type-accuracy=1.000000
# INFO:root:Epoch[2] Batch [0-16]	Speed: 14630.43 samples/sec	cross-entropy=0.001074	Scale Type-accuracy=1.000000
# INFO:root:Epoch[2] Train-cross-entropy=0.000928
# INFO:root:Epoch[2] Train-Scale Type-accuracy=1.000000
# INFO:root:Epoch[2] Time cost=0.042
# INFO:root:Saved checkpoint to "imputer_model/model-0002.params"
# INFO:root:Epoch[2] Validation-cross-entropy=0.007236
# INFO:root:Epoch[2] Validation-Scale Type-accuracy=1.000000
# INFO:root:Epoch[3] Batch [0-16]	Speed: 14546.19 samples/sec	cross-entropy=0.000803	Scale Type-accuracy=1.000000
# INFO:root:Epoch[3] Train-cross-entropy=0.000712
# INFO:root:Epoch[3] Train-Scale Type-accuracy=1.000000
# INFO:root:Epoch[3] Time cost=0.046
# INFO:root:Saved checkpoint to "imputer_model/model-0003.params"
# INFO:root:Epoch[3] Validation-cross-entropy=0.007839
# INFO:root:Epoch[3] Validation-Scale Type-accuracy=1.000000
# INFO:root:Epoch[4] Batch [0-16]	Speed: 13384.46 samples/sec	cross-entropy=0.000636	Scale Type-accuracy=1.000000
# INFO:root:Epoch[4] Train-cross-entropy=0.000573
# INFO:root:Epoch[4] Train-Scale Type-accuracy=1.000000
# INFO:root:Epoch[4] Time cost=0.042
# INFO:root:Saved checkpoint to "imputer_model/model-0004.params"
# INFO:root:Epoch[4] Validation-cross-entropy=0.008457
# INFO:root:Epoch[4] Validation-Scale Type-accuracy=1.000000
# INFO:root:Epoch[5] Batch [0-16]	Speed: 12302.41 samples/sec	cross-entropy=0.000522	Scale Type-accuracy=1.000000
# INFO:root:Epoch[5] Train-cross-entropy=0.000475
# INFO:root:Epoch[5] Train-Scale Type-accuracy=1.000000
# INFO:root:Epoch[5] Time cost=0.043
# INFO:root:Saved checkpoint to "imputer_model/model-0005.params"
# INFO:root:Epoch[5] Validation-cross-entropy=0.008896
# INFO:root:Epoch[5] Validation-Scale Type-accuracy=1.000000
# INFO:root:Epoch[6] Batch [0-16]	Speed: 12389.42 samples/sec	cross-entropy=0.000441	Scale Type-accuracy=1.000000
# INFO:root:Epoch[6] Train-cross-entropy=0.000401
# INFO:root:Epoch[6] Train-Scale Type-accuracy=1.000000
# INFO:root:Epoch[6] Time cost=0.042
# INFO:root:Saved checkpoint to "imputer_model/model-0006.params"
# INFO:root:No improvement detected for 5 epochs compared to 0.006920245003129821 last error obtained: 0.00933889729094517, stopping here
# INFO:root:
# ========== done (0.41672754287719727 s) fit model
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:4213: FutureWarning: 'is_extension_type' is deprecated and will be removed in a future version.  Use 'is_extension_array_dtype' instead.
#   if callable(index) or is_dict_like(index):

# %%
Scale_Type_imputed = scale_imputed_data['Scale Type_imputed']

# %% [markdown]
# ##### Imputed data set

# %%
scale_imputed_data = {'Well No': scale_data['Well No'], 'T': T_imputed, 'P': P_imputed, 'XCO2': XCO2_imputed, 'pH': pH_imputed, 'Ca2+': scale_data['Ca2+'], 'Na+': Na_imputed,
                      'Mg2+': Mg2_imputed, 'Fe2+': Fe2_imputed, 'HCO3-': scale_data['HCO3-'], 'SO4 2-': SO4_2_imputed, 'Cl-': Cl_imputed,
                      'CO3 2-': CO3_2_imputed, 'TDS': TDS_imputed, 'Inspection Result': scale_data['Inspection Result'],
       'Scale Type': Scale_Type_imputed}

# %%
scale_imputed_data = pd.DataFrame(data=scale_imputed_data)

# %%
scale_imputed_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541 entries, 0 to 540
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Well No            541 non-null    int64
#  1   T                  541 non-null    float64
#  2   P                  541 non-null    float64
#  3   XCO2               541 non-null    float64
#  4   pH                 541 non-null    float64
#  5   Ca2+               541 non-null    float64
#  6   Na+                541 non-null    float64
#  7   Mg2+               541 non-null    float64
#  8   Fe2+               541 non-null    float64
#  9   HCO3-              541 non-null    float64
#  10  SO4 2-             541 non-null    float64
#  11  Cl-                541 non-null    float64
#  12  CO3 2-             541 non-null    float64
#  13  TDS                541 non-null    float64
#  14  Inspection Result  541 non-null    int64
#  15  Scale Type         541 non-null    object
# dtypes: float64(13), int64(2), object(1)
# memory usage: 67.8+ KB

# %% [markdown]
# #### Average data imputed

# %%
scale_averaged_data = pd.DataFrame(scale_data.fillna(scale_data.mean()))

scale_averaged_data.sample(7)
# Out:
#      Well No           T           P  ...       TDS  Inspection Result  Scale Type
# 229       78  132.277778  849.976389  ...   73744.0                  1       CaCO3
# 73        42  132.277778  849.976389  ...  122515.0                  1       CaCO3
# 352      100  132.277778  849.976389  ...   48424.0                  1       CaCO3
# 86        44  132.277778  849.976389  ...  107631.0                  1       CaCO3
# 470      119  132.277778  849.976389  ...  107205.0                  0       CaCO3
# 77        43  132.277778  849.976389  ...   20070.0                  1       CaCO3
# 297       91  132.277778  849.976389  ...   68781.0                  1       CaCO3
#
# [7 rows x 16 columns]

# %%
scale_averaged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541 entries, 0 to 540
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Well No            541 non-null    int64
#  1   T                  541 non-null    float64
#  2   P                  541 non-null    float64
#  3   XCO2               541 non-null    float64
#  4   pH                 541 non-null    float64
#  5   Ca2+               541 non-null    float64
#  6   Na+                541 non-null    float64
#  7   Mg2+               541 non-null    float64
#  8   Fe2+               541 non-null    float64
#  9   HCO3-              541 non-null    float64
#  10  SO4 2-             541 non-null    float64
#  11  Cl-                541 non-null    float64
#  12  CO3 2-             541 non-null    float64
#  13  TDS                541 non-null    float64
#  14  Inspection Result  541 non-null    int64
#  15  Scale Type         540 non-null    object
# dtypes: float64(13), int64(2), object(1)
# memory usage: 67.8+ KB

# %% [markdown]
# #### Zero Imputed Data

# %%
scale_data_zeroed = scale_data.fillna(0)

scale_data_zeroed.sample(7)
# Out:
#      Well No      T       P  ...       TDS  Inspection Result  Scale Type
# 31        32  130.0  1115.0  ...   70988.0                  1       BaSO4
# 413      110    0.0     0.0  ...   76280.0                  1       CaCO3
# 536      129    0.0     0.0  ...   81271.0                  0       CaCO3
# 151       56    0.0     0.0  ...   82112.0                  1       CaCO3
# 197       64    0.0     0.0  ...  149240.0                  1       CaCO3
# 99        45    0.0     0.0  ...   94346.0                  1       CaCO3
# 203       65    0.0     0.0  ...  176274.0                  1       CaCO3
#
# [7 rows x 16 columns]

# %%
scale_data_zeroed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541 entries, 0 to 540
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Well No            541 non-null    int64
#  1   T                  541 non-null    float64
#  2   P                  541 non-null    float64
#  3   XCO2               541 non-null    float64
#  4   pH                 541 non-null    float64
#  5   Ca2+               541 non-null    float64
#  6   Na+                541 non-null    float64
#  7   Mg2+               541 non-null    float64
#  8   Fe2+               541 non-null    float64
#  9   HCO3-              541 non-null    float64
#  10  SO4 2-             541 non-null    float64
#  11  Cl-                541 non-null    float64
#  12  CO3 2-             541 non-null    float64
#  13  TDS                541 non-null    float64
#  14  Inspection Result  541 non-null    int64
#  15  Scale Type         541 non-null    object
# dtypes: float64(13), int64(2), object(1)
# memory usage: 67.8+ KB

# %% [markdown]
# #### New Data Set Visualization
#
# The new data sets are visualized to see if the data behaviour is similar to the original data set.

# %%
# Plot to check scale_imputed_data T column distribution

sns.distplot(scale_imputed_data['T'], bins=20);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Original data set distribution
scale_data.hist(figsize=(14, 12));

# %%
# Plotting to check the disparity or similarity between the original data set and the imputed data set
scale_imputed_data.hist(figsize=(14,12));

# %%
# Plotting to check the disparity or similarity between the original data set and the data set where averages replaced nulls
scale_averaged_data.hist(figsize=(14,12));

# %%
# Plotting to check the disparity or similarity between the original data set and the data set where zeros replaced nulls
scale_data_zeroed.hist(figsize=(14,12));

# %% [markdown]
# ## Model Building

# %% [markdown]
# ##### Chooosing the right metrics for evaluation
#
# For evaluating the performance of our models to determine how correctly it classifies the occurence of scale or not, we will refer to `scale` (1) as the positive outcome and `no scale` (0) as the negative outcome.
#
# scale = positive outcome
# no scale = negative outcome
#
# *insert confusion matrix"
#
# **The AUC - ROC curve**
# The Reciever Operating Characteristic curve, ROC curve is a plot of the model's 'Recall' versus the model's 'False Positive Rate'. This type of metric indicates the probability of model classifying a proportion of possitve values corrrectly and classifying also a proportion the negative values correctly.
#   **Recall** : The fraction of positves correctly classified in the all the data positives. Mathematically:
#       Recall = TP / (TP + FN)
#     A high recall is desirable.
#
#   **False Positive Rate**: The FPR is the proportion of negatives that are falsely as classified positives among the True negatives and palse positives (i.e. total negatives in the data set).
#       FPR = FP/(TN + FP)
#     A low FPR is desirable.
#
# A plot of Recall Versus FPR gives the ROC Curve below.
#
# *insert ROC curve"
#
# The best performing model is the one nearest to the top left corner of the plot (high Recall and Low False Positive Rates)
#
# This evaluation metric was chosen to evaluate the models built in this research for two major reasons:
# 1. **Relevance to research problem**: the efficiency of the model and the expected advantage of applying it . Correctly predicted scale appearance enables fast proactive response which saves cost. Falsely classified scale apperances that eventually occur will be costly, In this case a high recall will achieve this aim.
# If no scale situations are falsely classified as scale, the company's resources are wasted, so very low false positives (FPR) shows a good performance.
#
# 2. **Data imbalance**: The ROC curve metric gives the rates in fractions that are not dependent on the data population size for the different outcomes. This means that:
# Recall gives a fraction of TP as a ratio of the total population of positives in the data set. Whether the data set is balanced or not, this fraction will be the same. It works the same way with the FPR its denominator implies that it is dependent on only the negative values of the data set. The data set used for model building in this research having more positive outcomes will not be biasedly evaluated by these fractions.
#
#
# **AUC** is the area under an ROC curve calculated for a model. Its values ranges from 0 to 1 as the ROC curve is a plot of probabilities. A model with 0.5 as AUC_score is a random performing model, it gives the right or wrong answers at random. The closer the AUC_score to 1, the better the model's performances. The final model picked from the 4 models experimented was evaluated based on its ROC curve and AUC_score using the criteria mentioned above.
#
# *analyze the output of comparing the ROC curves and the AUC curves"

# %%
# Import performance metrics
from sklearn.metrics import roc_curve, plot_roc_curve, auc

# Train_test_split for 
from sklearn.model_selection import train_test_split

# %% [markdown]
# scale_data.columns
#
# roc_auc_score(y, model.predict_proba(X)[:, 1])
#
# roc_auc_score(y, model.decision_function(X))
#
# Dropped Scale Type column because

# %%
# Function for model building and evaluation

def build_model(model, dataset):

  # Splitting data for training and testing
  feature_col = ['T', 'P', 'XCO2', 'pH', 'Ca2+', 'Na+', 'Mg2+', 'Fe2+',
       'HCO3-', 'SO4 2-', 'Cl-', 'CO3 2-', 'TDS']
  target_col = 'Inspection Result'

  X = dataset[feature_col]
  y = dataset[target_col]

  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=20)

  # Fit training data
  model.fit(X_train, y_train)

  # Make prediction
  y_score = model.predict_proba(X_test)[:, 1]

  # Evaluate model using ROC curve and AUC_score

  # Compute ROC curve
  fpr, tpr, thresholds = roc_curve(y_test, y_score)

  # auc_score
  roc_auc = auc(fpr, tpr)


  # AUC_score for training and test data 

  print('Model training auc_score: {}'.format(roc_auc))
  print('Model test auc_score: {}'.format(roc_auc))

  # Plot the ROC curve for the model


  return {'auc_score': roc_auc, 
          'fpr': fpr,
          'tpr': tpr,
          'threshold': thresholds,
          'y_score': y_score,
          'y_test': y_test
          }

# %%
# Instantiate an evaluation dictionary for test and training scores
model_dic = {}

# %%
# A function for comparing the performance of the different models

def performance_score():
  """
  This function consists of a for loop that iterates over the dictionary: model_dic 
  to print out model name and evaluation scores.
    
  """
  for key in model_dic:
    # Print model name
    print('Model:', key )
        
    # Print model training score
    print('Test AUC score: {}'.format((model_dic[key]['auc_score']).round(2)))
        
        
    print('\n') 
  print()

    # Plot ROC_curve for all the models on one graph

# %% [markdown]
# ##### SVM Classifier

# %%
from sklearn.svm import SVC

# Instantiate model
scale_SVC_model = SVC(kernel='linear', probability=True,
                                 random_state=0)

model_dic['SVC model (averaged)'] = build_model(model=scale_SVC_model, dataset=scale_averaged_data)
# Out:
# Model training auc_score: 0.8064382654750083
# Model test auc_score: 0.8064382654750083

# %%
# SVC algorithm training on imputed data set
model_dic['SVC model (imputed)'] = build_model(model=scale_SVC_model, dataset=scale_imputed_data)
# Out:
# Model training auc_score: 0.7826050976497849
# Model test auc_score: 0.7826050976497849

# %%
# SVC algorithm training on data set where zeros replace nulls
model_dic['SVC model (zeroed)'] = build_model(model=scale_SVC_model, dataset=scale_data_zeroed)
# Out:
# Model training auc_score: 0.18809996689837805
# Model test auc_score: 0.18809996689837805

# %%
performance_score()
# Out:
# Model: SVC model (averaged)
# Test AUC score: 0.81
#
#
# Model: SVC model (imputed)
# Test AUC score: 0.78
#
#
# Model: SVC model (zeroed)
# Test AUC score: 0.19

# %% [markdown]
# ##### Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression

scale_logistic = LogisticRegression()

# Logistic algorithm trained on data set of null replaced with averages
model_dic['Logistic Regression Model (averaged) '] = build_model(model=scale_logistic, dataset=scale_averaged_data)
# Out:
# Model training auc_score: 0.8488083416087387
# Model test auc_score: 0.8488083416087387
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
model_dic['Logistic Regression Model (averaged) ']['threshold']
# Out:
# array([2.00000000e+00, 9.99999997e-01, 9.97445523e-01, 9.93939800e-01,
#        9.92419553e-01, 9.78702823e-01, 9.78209608e-01, 9.61058726e-01,
#        9.59850605e-01, 9.42086337e-01, 9.32265862e-01, 8.87459905e-01,
#        8.86320991e-01, 8.72212857e-01, 8.68534318e-01, 8.03273084e-01,
#        7.98002434e-01, 7.91184321e-01, 7.88778183e-01, 7.30840741e-01,
#        7.27102788e-01, 6.05362388e-01, 5.99906192e-01, 5.99864744e-01,
#        5.68227435e-01, 5.65263765e-01, 5.41541698e-01, 5.40337755e-01,
#        5.22565040e-01, 5.05001867e-01, 4.82040839e-01, 4.69505259e-01,
#        4.60603052e-01, 4.53866319e-01, 4.16236031e-01, 4.15000578e-01,
#        4.12159443e-01, 3.90479777e-01, 3.03365678e-01, 2.79342846e-01,
#        1.55159862e-01, 1.40896791e-01, 2.72336297e-02, 1.98517848e-02,
#        2.74327585e-04])

# %%
# Logistic algorithm trained on imputed data set
model_dic['Logistic Regression Model (imputed)'] = build_model(model=scale_logistic, dataset=scale_imputed_data)
# Out:
# Model training auc_score: 0.7822740814299901
# Model test auc_score: 0.7822740814299901
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
# Logistic algorithm trained on data set of null replaced with zeros
model_dic['Logistic Regression Model (zeroed)'] = build_model(model=scale_logistic, dataset=scale_data_zeroed)
# Out:
# Model training auc_score: 0.695878848063555
# Model test auc_score: 0.695878848063555
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %% [markdown]
# ##### Decision  Tree Model

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
# Instantiate model
scale_Decision_Tree = DecisionTreeClassifier(random_state=20)

# Decision Tree algorithm trained on data set with null values replaced by averages
model_dic['Decision Tree Model (averaged)'] = build_model(model=scale_Decision_Tree, dataset=scale_averaged_data)
# Out:
# Model training auc_score: 0.9102946044356174
# Model test auc_score: 0.9102946044356174

# %%
model_dic['Decision Tree Model (averaged)']['threshold']
# Out:
# array([2. , 1. , 0.5, 0. ])

# %%
# Decision Tree algorithm trained on inputed data set
model_dic['Decision Tree Model (zeroed)'] = build_model(model=scale_Decision_Tree, dataset=scale_data_zeroed)
# Out:
# Model training auc_score: 0.8732207878186031
# Model test auc_score: 0.8732207878186031

# %%
# Decision Tree algorithm trained on data set with null values replaced by zeros
model_dic['Decision Tree Model (imputed)'] = build_model(model=scale_Decision_Tree, dataset=scale_imputed_data)
# Out:
# Model training auc_score: 0.8831512744124461
# Model test auc_score: 0.8831512744124461

# %%
performance_score()
# Out:
# Model: SVC model (averaged)
# Test AUC score: 0.81
#
#
# Model: SVC model (imputed)
# Test AUC score: 0.78
#
#
# Model: SVC model (zeroed)
# Test AUC score: 0.19
#
#
# Model: Logistic Regression Model (averaged)
# Test AUC score: 0.85
#
#
# Model: Logistic Regression Model (imputed)
# Test AUC score: 0.78
#
#
# Model: Logistic Regression Model (zeroed)
# Test AUC score: 0.7
#
#
# Model: Decision Tree Model (averaged)
# Test AUC score: 0.91
#
#
# Model: Decision Tree Model (zeroed)
# Test AUC score: 0.87
#
#
# Model: Decision Tree Model (imputed)
# Test AUC score: 0.88

# %% [markdown]
# ##### Predicted Result Visualization

# %%
# Plot ROC for all the models
plt.subplots(figsize=(16,16))
plt.plot(model_dic['SVC model (averaged)']['fpr'], model_dic['SVC model (averaged)']['tpr'], linestyle='-', label = 'SVC_A {}'.format(model_dic['SVC model (averaged)']['auc_score']))
plt.plot(model_dic['SVC model (imputed)']['fpr'], model_dic['SVC model (imputed)']['tpr'], linestyle='-', label = 'SVC_I {}'.format(model_dic['SVC model (imputed)']['auc_score']))
plt.plot(model_dic['SVC model (zeroed)']['fpr'], model_dic['SVC model (zeroed)']['tpr'], linestyle='-', label = 'SVC_Z {}'.format(model_dic['SVC model (zeroed)']['auc_score']))
plt.plot(model_dic['Logistic Regression Model (averaged) ']['fpr'], model_dic['Logistic Regression Model (averaged) ']['tpr'], linestyle='-', label = 'Logistic_A {}'.format(model_dic['Logistic Regression Model (averaged) ']['auc_score']))
plt.plot(model_dic['Logistic Regression Model (imputed)']['fpr'], model_dic['Logistic Regression Model (imputed)']['tpr'], linestyle='-', label = 'Logistic_I {}'.format(model_dic['Logistic Regression Model (imputed)']['auc_score']))
plt.plot(model_dic['Logistic Regression Model (zeroed)']['fpr'], model_dic['Logistic Regression Model (zeroed)']['tpr'], linestyle='-', label = 'Logistic_Z {}'.format(model_dic['Logistic Regression Model (zeroed)']['auc_score']))
plt.plot(model_dic['Decision Tree Model (averaged)']['fpr'], model_dic['Decision Tree Model (averaged)']['tpr'], linestyle='-', label = 'DecisionT_A {}'.format(model_dic['Decision Tree Model (averaged)']['auc_score']))
plt.plot(model_dic['Decision Tree Model (imputed)']['fpr'], model_dic['Decision Tree Model (imputed)']['tpr'], linestyle='-', label = 'DecisionT_I {}'.format(model_dic['Decision Tree Model (imputed)']['auc_score']))
plt.plot(model_dic['Decision Tree Model (zeroed)']['fpr'], model_dic['Decision Tree Model (zeroed)']['tpr'], linestyle='-', label = 'DecisionT_Z {}'.format(model_dic['Decision Tree Model (zeroed)']['auc_score']))


plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')

plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ### Table containing all predicted results

# %%
prediction_results = pd.DataFrame(data={'Inspection Result': model_dic['Decision Tree Model (averaged)']['y_test'] ,'SVC model prediction': model_dic['SVC model (averaged)']['y_score'] , 'Logistic model prediction': model_dic['Logistic Regression Model (averaged) ']['y_score'], 'DecisionTree model prediction': model_dic['Decision Tree Model (averaged)']['y_score']})

# %%
tablename = prediction_results.head(10)
tablename
# Out:
#      Inspection Result  ...  DecisionTree model prediction
# 74                   1  ...                            1.0
# 457                  0  ...                            0.0
# 320                  1  ...                            1.0
# 387                  1  ...                            1.0
# 327                  1  ...                            1.0
# 353                  1  ...                            1.0
# 276                  1  ...                            1.0
# 536                  0  ...                            0.0
# 30                   1  ...                            1.0
# 230                  1  ...                            1.0
#
# [10 rows x 4 columns]
